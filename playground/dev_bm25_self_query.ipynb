# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('../')

# %%
import tomllib

with open('../.notion_databases.toml', 'rb') as f:
    _DATABASES_NOTION = tomllib.load(f)

with open('../.tokens.toml', 'rb') as f:
    _TOKENS = tomllib.load(f)

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.1.7
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /Users/fred/micromamba/envs/my-notion-companion/lib/python3.12/site-packages
# Requires: aiohttp, dataclasses-json, jsonpatch, langchain-community, langchain-core, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-experimental

# %%
# from my_notion_companion.notion_loader import NotionLoader

# notion_loader = NotionLoader(_TOKENS, _DATABASES_NOTION)
# notion_loader._load_databases()

# %%
# notion_loader._format_data()
# print(len(notion_loader.data_formatted))

# notion_loader.export_to_pickle('../data/notion.pkl')

# %%
import pickle

with open('../data/notion.pkl', 'rb') as f:
    docs = pickle.load(f)

# %%
len(docs)
# Out:
# 226

# %%
from langchain_community.llms import LlamaCpp

with open('../.config.toml', 'rb') as f:
    _CONFIGS = tomllib.load(f)
    
llm = LlamaCpp(
    model_path=_CONFIGS['model_path']+'/'+_CONFIGS['model_mapping'][_CONFIGS['model_name']],
    name=_CONFIGS['model_name'], 
    **_CONFIGS['llm']
)
# Out:
# /Users/fred/micromamba/envs/my-notion-companion/lib/python3.12/site-packages/langchain_core/utils/utils.py:159: UserWarning: WARNING! conversation is not default parameter.
#                 conversation was transferred to model_kwargs.
#                 Please confirm that conversation is what you intended.
#   warnings.warn(
# llama_model_loader: loaded meta data with 21 key-value pairs and 291 tensors from /Users/fred/Documents/models/zephyr-7b-beta.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = huggingfaceh4_zephyr-7b-beta
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 10000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 15
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  19:            tokenizer.ggml.padding_token_id u32              = 2
# llama_model_loader: - kv  20:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  193 tensors
# llama_model_loader: - type q6_K:   33 tensors
# llm_load_vocab: special tokens definition check successful ( 259/32000 ).
# llm_load_print_meta: format           = GGUF V3 (latest)
# llm_load_print_meta: arch             = llama
# llm_load_print_meta: vocab type       = SPM
# llm_load_print_meta: n_vocab          = 32000
# llm_load_print_meta: n_merges         = 0
# llm_load_print_meta: n_ctx_train      = 32768
# llm_load_print_meta: n_embd           = 4096
# llm_load_print_meta: n_head           = 32
# llm_load_print_meta: n_head_kv        = 8
# llm_load_print_meta: n_layer          = 32
# llm_load_print_meta: n_rot            = 128
# llm_load_print_meta: n_embd_head_k    = 128
# llm_load_print_meta: n_embd_head_v    = 128
# llm_load_print_meta: n_gqa            = 4
# llm_load_print_meta: n_embd_k_gqa     = 1024
# llm_load_print_meta: n_embd_v_gqa     = 1024
# llm_load_print_meta: f_norm_eps       = 0.0e+00
# llm_load_print_meta: f_norm_rms_eps   = 1.0e-05
# llm_load_print_meta: f_clamp_kqv      = 0.0e+00
# llm_load_print_meta: f_max_alibi_bias = 0.0e+00
# llm_load_print_meta: n_ff             = 14336
# llm_load_print_meta: n_expert         = 0
# llm_load_print_meta: n_expert_used    = 0
# llm_load_print_meta: rope scaling     = linear
# llm_load_print_meta: freq_base_train  = 10000.0
# llm_load_print_meta: freq_scale_train = 1
# llm_load_print_meta: n_yarn_orig_ctx  = 32768
# llm_load_print_meta: rope_finetuned   = unknown
# llm_load_print_meta: model type       = 7B
# llm_load_print_meta: model ftype      = Q4_K - Medium
# llm_load_print_meta: model params     = 7.24 B
# llm_load_print_meta: model size       = 4.07 GiB (4.83 BPW)
# llm_load_print_meta: general.name     = huggingfaceh4_zephyr-7b-beta
# llm_load_print_meta: BOS token        = 1 '<s>'
# llm_load_print_meta: EOS token        = 2 '</s>'
# llm_load_print_meta: UNK token        = 0 '<unk>'
# llm_load_print_meta: PAD token        = 2 '</s>'
# llm_load_print_meta: LF token         = 13 '<0x0A>'
# llm_load_tensors: ggml ctx size =    0.22 MiB
# ggml_backend_metal_buffer_from_ptr: allocated buffer, size =  4095.06 MiB, ( 4095.12 / 10922.67)
# llm_load_tensors: offloading 32 repeating layers to GPU
# llm_load_tensors: offloaded 32/33 layers to GPU
# llm_load_tensors:        CPU buffer size =  4165.37 MiB
# llm_load_tensors:      Metal buffer size =  4095.05 MiB
# ..................................................................................................
# llama_new_context_with_model: n_ctx      = 4096
# llama_new_context_with_model: freq_base  = 10000.0
# llama_new_context_with_model: freq_scale = 1
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M2 Pro
# ggml_metal_init: picking default device: Apple M2 Pro
# ggml_metal_init: default.metallib not found, loading from source
# ggml_metal_init: GGML_METAL_PATH_RESOURCES = nil
# ggml_metal_init: loading '/Users/fred/micromamba/envs/my-notion-companion/lib/python3.12/site-packages/llama_cpp/ggml-metal.metal'
# ggml_metal_init: GPU name:   Apple M2 Pro
# ggml_metal_init: GPU family: MTLGPUFamilyApple8  (1008)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction support   = true
# ggml_metal_init: simdgroup matrix mul. support = true
# ggml_metal_init: hasUnifiedMemory              = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 11453.25 MB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =   512.00 MiB, ( 4608.69 / 10922.67)
# llama_kv_cache_init:      Metal KV buffer size =   512.00 MiB
# llama_new_context_with_model: KV self size  =  512.00 MiB, K (f16):  256.00 MiB, V (f16):  256.00 MiB
# llama_new_context_with_model:        CPU input buffer size   =    80.04 MiB
# ggml_backend_metal_buffer_type_alloc_buffer: allocated buffer, size =  1184.02 MiB, ( 5792.70 / 10922.67)
# llama_new_context_with_model:      Metal compute buffer size =  1184.01 MiB
# llama_new_context_with_model:        CPU compute buffer size =   314.00 MiB
# llama_new_context_with_model: graph splits (measure): 4
# AVX = 0 | AVX_VNNI = 0 | AVX2 = 0 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 0 | NEON = 1 | ARM_FMA = 1 | F16C = 0 | FP16_VA = 1 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 0 | SSSE3 = 0 | VSX = 0 | MATMUL_INT8 = 0 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.ggml.padding_token_id': '2', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '8', 'llama.context_length': '32768', 'llama.attention.head_count': '32', 'llama.rope.freq_base': '10000.000000', 'llama.rope.dimension_count': '128', 'general.file_type': '15', 'llama.feed_forward_length': '14336', 'llama.embedding_length': '4096', 'llama.block_count': '32', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'general.name': 'huggingfaceh4_zephyr-7b-beta'}

# %%
from my_notion_companion.retriever import BM25SelfQueryRetriever

retriever_bm25 = BM25SelfQueryRetriever(llm, docs, _CONFIGS)
# Out:
# 2024-03-04 20:21:28.000 | INFO     | my_notion_companion.document_filter:__init__:15 - Setting metadata fuzzy match threshold to: 0.8.

# %%
retriever_bm25.invoke("“寡人之于国也”下一句是什么？来自哪里？")
# Out:
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.93 ms /    20 runs   (    0.10 ms per token, 10346.61 tokens per second)
# llama_print_timings: prompt eval time =    8960.06 ms /   921 tokens (    9.73 ms per token,   102.79 tokens per second)
# llama_print_timings:        eval time =     683.16 ms /    19 runs   (   35.96 ms per token,    27.81 tokens per second)
# llama_print_timings:       total time =    9685.65 ms /   940 tokens
# 2024-03-04 20:01:02.741 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['寡人之于国也']
# search domains:['无']
# 2024-03-04 20:01:02.741 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/4m/z0fvcltx31xcv13t79qsnb8r0000gn/T/jieba.cache
# Loading model cost 0.385 seconds.
# Prefix dict has been built successfully.
# [Document(page_content='国之父兄请曰：“昔者夫差耻吾君于诸侯之国，今越国亦节（克制）矣，请报之。”勾践辞曰：“昔者之战也，非二三子之罪也，寡人之罪也。如寡人者，安与知耻？请姑（暂且）无庸（用）战。”父兄又请曰：“越四封之内，亲吾君也，犹父母也。子而思报父母之仇，臣而思报君之仇，其有敢不尽力者乎？请复战！”勾践既许之，乃致其众而誓之，曰：“寡人闻古之贤君，不患其众之不足也，而患其志行之少耻也。今夫差衣水犀之甲者亿有三千，不患其志行之少耻也，而患其众之不足也。今寡人将助天灭之。吾不欲匹夫之勇也，欲其旅（俱）进旅退。进则思赏，退则思刑；如此，则有常赏。进不用命，退则无耻；如此，则有常刑。”\n果行，国人皆劝（勉励）。父勉其子，兄勉其弟，妇勉其夫，曰：“孰是君也，而可无死乎？”是故败吴于囿，又败之于没，又郊败之。遂灭吴。', metadata={'author': None, 'tags': '古文', 'name': '高中古诗文', 'id': '0c77a756-a81d-486d-83de-2de6fb7e9e5d', 'source': '读书笔记（文学）', 'date_start': 20130812}),
#  Document(page_content='《寡人之于国也》（孟子）\n梁惠王曰：“寡人之于国也，尽心焉耳矣。河内凶，则移其民于河东，移其粟于河内；河东凶亦然。察邻国之政，无如寡人之用心者。邻国之民不加少，寡人之民不加多，何也？”\n孟子对曰：“王好（hào）战，请以战喻。填然鼓之，兵刃既接，弃甲曳(yè)兵而走，或百步而后止，或五十步而后止。以五十步笑百步，则何如？”\n曰：“不可！直不百步耳，是亦走也。”\n曰：“王如知此，则无望民之多于邻国也。”\n“不违农时，谷不可胜（shēng，尽）食也。数（cù）罟（gǔ）不入洿（wū）池，鱼鳖不可胜食也。斧斤以时入山林，材木不可胜用也。谷与鱼鳖不可胜食，材木不可胜用，是使民养生丧（sāng）死无憾也。养生丧死无憾，王道之始也。\n“五亩之宅，树之以桑，五十者可以衣（yì）帛矣。鸡豚狗彘（zhì）之畜（xù），勿失其时，七十者可以食肉矣。百亩之田，勿夺其时，数口之家可以无饥矣；谨庠（xiáng）序之教，申之以孝悌之义，颁白者不负戴（顶）于道路矣。七十者衣帛食肉，黎民不饥不寒，然而不王者，未之有也。', metadata={'author': None, 'tags': '古文', 'name': '高中古诗文', 'id': '0c77a756-a81d-486d-83de-2de6fb7e9e5d', 'source': '读书笔记（文学）', 'date_start': 20130812}),
#  Document(page_content='勾践之地，南至于句无，北至于御儿，东至于鄞（yín），西至于姑蔑，广运百里，乃致其父母昆弟而誓之，曰：“寡人闻，古之贤君，四方之民归之，若水之归下也。今寡人不能，将帅二三子（你们）夫妇以蕃（繁殖）。”令壮者无取老妇，令老者无取壮妻；女子十七不嫁，其父母有罪；丈夫二十不取，其父母有罪。将免（通“娩”）者以告，公令医守之。生丈夫，二壶酒，一犬；生女子，二壶酒，一豚；生三人，公与之母；生二子，公与之饩（xì）。当室者死，三年释其政；支子死，三月释其政；必哭泣葬埋之如其子。令孤子、寡妇、疾疹（chèn）、贫病者，纳宦其子。其达士，洁其居，美其服，饱其食，而摩厉之于义。四方之士来者，必庙礼之。勾践载稻与脂于舟以行。国之孺子之游者，无不餔（哺）也，无不歠（chuò，啜）也：必问其名。非其身之所种则不食，非其夫人之所织则不衣。十年不收于国，民俱有三年之食。', metadata={'author': None, 'tags': '古文', 'name': '高中古诗文', 'id': '0c77a756-a81d-486d-83de-2de6fb7e9e5d', 'source': '读书笔记（文学）', 'date_start': 20130812}),
#  Document(page_content='《勾践灭吴》（国语）\n越王勾践栖于会稽之上，乃号令于三军曰：“凡我父兄昆弟及国子姓，有能助寡人谋而退吴者，吾与之共知越国之政。”大夫种进对曰：“臣闻之，贾（gǔ）人夏则资皮，冬则资絺（chī），旱则资舟，水则资车，以待乏也。夫虽无四方之忧，然谋臣与爪牙之士，不可不养而择也。譬如蓑笠，时雨既至，必求之。今君王既栖于会稽之上，然后乃求谋臣，无乃后乎？”勾践曰：“苟得闻子大夫之言，何后之有？”执其手而与之谋。遂使之行成（讲和）于吴。\n勾践说于国人曰：“寡人不知其力之不足也，而又与大国执仇，以暴露百姓之骨于中原，此则寡人之罪也。寡人请更。”于是葬死者，问伤者，养生者；吊有忧，贺有喜；送往者，迎来者；去民之所恶，补民之不足。然后卑事夫差，宦士三百人于吴，其身亲为夫差前马。', metadata={'author': None, 'tags': '古文', 'name': '高中古诗文', 'id': '0c77a756-a81d-486d-83de-2de6fb7e9e5d', 'source': '读书笔记（文学）', 'date_start': 20130812}),
#  Document(page_content='高一上\n课文\n\n《烛之武退秦师》（左传）\n晋侯、秦伯围郑，以其无礼于晋，且贰于楚也。晋军函陵，秦军氾（fán）南。\n佚（yì）之狐言于郑伯曰：“国危矣，若使烛之武见秦君，师必退。”公从之。辞曰：“臣之壮也，犹不如人；今老矣，无能为也已。”公曰：“吾不能早用子、今急而求子，是寡人之过也。然郑亡，子亦有不利焉！”许之。\n夜缒（zhuì）而出，见秦伯，曰：“秦、晋围郑，郑既知亡矣。若亡郑而有益于君，敢以烦执事。越国以鄙远，君知其难也，焉用亡郑以陪邻？邻之厚，君之薄也。若舍郑以为东道主，行李之往来，共（gōng）其乏困，君亦无所害。且君尝为晋君赐矣，许君焦、瑕，朝济而夕设版焉，君之所知也。夫（fú）晋，何厌之有？既东封郑，又欲肆其西封，若不阙（quē）秦，将焉取之？阙秦以利晋，唯君图之。”秦伯说（yuè），与郑人盟。使杞子、逢（páng）孙、杨孙戍之，乃还。\n子犯请击之。公曰：“不可。微夫人之力不及此。因人之力而敝之，不仁；失其所与，不知；以乱易整，不武。吾其还也。”亦去之。\n\n附：《左传》是我国第一部编年史著作。', metadata={'author': None, 'tags': '古文', 'name': '高中古诗文', 'id': '0c77a756-a81d-486d-83de-2de6fb7e9e5d', 'source': '读书笔记（文学）', 'date_start': 20130812})]

# %%
retriever_bm25.invoke("“每人都以为他有一种主要的美德。”是出自哪里？请从“读书笔记（文学）”中找到答案。")
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4027.91 ms
# llama_print_timings:      sample time =       3.02 ms /    34 runs   (    0.09 ms per token, 11265.74 tokens per second)
# llama_print_timings: prompt eval time =     535.08 ms /    72 tokens (    7.43 ms per token,   134.56 tokens per second)
# llama_print_timings:        eval time =    1167.03 ms /    33 runs   (   35.36 ms per token,    28.28 tokens per second)
# llama_print_timings:       total time =    1755.57 ms /   105 tokens
# 2024-03-04 16:48:14.120 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['每人都以为他有一种主要的美德。']
# search domains:['读书笔记（文学）']
# 2024-03-04 16:48:14.121 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 16:48:14.688 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.540
# [Document(page_content='了不起的盖茨比\n【美】菲茨杰拉德\n\n作者简介：20年代“爵士时代”的发言人和“迷惘的一代”的代表作家之一。他成名后尽管勤奋笔耕，但讲究排场、挥霍无度，染病后终日酗酒，去世时年仅44岁。他的小说生动地反映了20年代“美国梦”的破灭，展示了大萧条时期美国上层社会“荒原时代”的精神面。菲茨杰拉德是美国最具有诗人特质和梦想家气质和风格的小说家，他把自己和济慈划归同一种类型：“成熟得早的才华往往是属于诗人类型的，我自己基本上就是如此。”\n\n\n1. 每个人都以为他自己至少有一种主要的美德。\n\n\n2. 景物描写：\n\n1） 草坪从海滩起步，直奔大门，足足有四分之一英里，一路跨过日晷、砖径和火红的花园——最后跑到房子跟前，仿佛借助奔跑的势头，爽性变成绿油油的常春藤，沿着墙往上爬。\n\n2） 西卵和纽约之间大约一半路程的地方，汽车路匆匆忙忙跟铁路回合，它在铁路旁边跑上四分之一英里，为的是要躲开一片荒凉的地方。这是一个灰烬的山谷——一个离奇古怪的农场，在这里灰烬像麦子一样生长，长成小山小丘和奇怪形状的园子；在这里灰烬堆成房屋、烟囱和炊烟的形式，最后，经过超绝的努力，堆成一个个灰蒙蒙的人，隐隐约约地在走动。', metadata={'author': '【美】菲茨杰拉德', 'tags': '小说', 'name': '了不起的盖茨比 【美】菲茨杰拉德', 'id': '86922d74-5b16-40d1-a14d-9132a2d391b4', 'source': '读书笔记（文学）', 'date_start': 20130906}),
#  Document(page_content='最常见的艺术门类是诗歌、音乐、舞蹈（三种在起源时是统一体），建筑、雕刻和绘画（合称“造形艺术”），戏剧、小说以及近代歌剧、哑剧和电影剧之类综合性艺术。这些艺术之间的分别和关系，自从莱辛的《拉奥孔》问世以来，一直是西方美学界研究和讨论的问题。德国美学家们一般把艺术分为“空间性的”和“时间性的”两大类。属于空间艺术的有建筑、雕刻和绘画，其功用主要是“状物”，或写静态，描绘在空间中直立和平铺并列有事物形状；所涉及的感官主要是视觉，所用的媒介主要是线条和颜色。属于时间艺术的主要有舞蹈、音乐、诗歌和一般文学，其功用主要是叙事抒情，写动态，描绘的时间上先后承续的事物发展过程，所涉及的感官较多，音乐较单纯，只涉及听觉和节奏感中筋肉运动感觉，舞蹈、诗歌和一般文学则视觉、听觉和筋肉运动感觉都起作用。时间艺术在所用的媒介方面有一个值得重视的差异，这就是其它各种艺术的媒介如声音、线条、色彩之类都是感性的，即可凭感官直接觉察到的；至于文学则用语言为媒介，而语言中的文字却只是代表观念的一种符号，本身并无意义，例如“人”这一观念，各民族用来代表它的文字符号各不相同，英文用man，法文用homme，德文用mens', metadata={'author': '朱光潜', 'tags': '散文', 'name': '谈美书简 朱光潜', 'id': '7abcc8ac-0213-43be-9232-74548bde9f69', 'source': '读书笔记（文学）', 'date_start': 20150321}),
#  Document(page_content='小品文简介\n“小品”一词，来自佛学，本指佛经的节本。《世说新语・文学》：“殷中军(浩)读小品，下二百签，皆是精微。”刘孝标注云：“释氏《辨空》，经有详者焉，有略者焉；详者为大品，略者为小品。”可见，“小品”本来是就“大品”相对而言，是篇幅上的区分，而不是题材或体裁的区分。小品一词，后来运用到文学领域，同样也没有严格的明确的定义，凡是短篇杂记一类文章，均可称之为小品\n。题材的包容和体裁的自由，可以说是小品文的主要特点。准确地说，“小品”是一种“文类”，可以包括许多具体的文体。\n事实上，在明人的小品文集中，许多文体，如尺牍、游记、日记、序跋，乃至骈文、辞赋、小说等几乎所有的文体，都可以成为“小品”。尽管如此，从阅读和研究的习惯来说，小品文还是有比较宽泛的界定，通常所称的小品文，主要还是就文体而言，指篇幅短小、文辞简约、情趣盎然、韵味隽永的散文作品。\n小品文作为一种文体的兴盛，在明清时期，主要在晚明阶段。而小品文的渊源，则仍可追溯到先秦时期。', metadata={'author': '【明】 张岱', 'tags': '古文', 'name': '西湖梦寻·陶庵梦忆 【明】 张岱', 'id': 'fb44bfdb-ab57-4ecd-ad90-0da8710665f3', 'source': '读书笔记（文学）', 'date_start': 20141119}),
#  Document(page_content='【自我和他人】\n一个人之所以不爱自己，甚至厌烦自己，是因为缺乏灵性即精神性。这样的人不够有灵性以自娱，于是感到无聊，希望在琐碎的日常劳作——所谓为他人生活——中忘掉这个空虚的自我。\n\n\n【性爱伦理学】\n在爱情中，双方感情的满足程度取决于感情较弱的那一方的感情。如果甲对乙有十分爱，乙对甲只有五分爱，则他们都只能得到五分的满足。剩下的那五分欠缺，在甲会成为一种遗憾，在乙会成为一种苦恼。\n\n\n【性爱美学】\n恋爱，人生中最美丽的时刻。如同黎明和黄昏，沐浴在柔和金光中的一切景物都变美了，包括那个美人儿。恋爱中的人以为那个美人儿是光源，其实她也是被照亮的景物。\n\n\n【婚姻与爱情】\n性是肉体生活，遵循快乐原则。爱情是精神生活，遵循理想原则。婚姻是社会生活，遵循现实原则。婚姻的困难在于，如何在同一个异性身上把三者统一起来，不让习以为常麻痹性的诱惑和快乐，不让琐碎现实损害爱的激情和理想。', metadata={'author': '周国平', 'tags': '散文', 'name': '风中的纸屑 【中】周国平', 'id': '3a99800e-23cd-40c7-88c6-dbe48e5dc048', 'source': '读书笔记（文学）', 'date_start': 20140620}),
#  Document(page_content='凯蒂悠闲自得地坐在她的椅子上，眼含笑意看着韦丁顿，手上则把她的结婚戒指不停地转来转去。\n“毫无疑问他会仕途畅达。他深谙官场上的那一套。在我有生之年一定有幸尊称他为阁下大人，在他登场时为他起立致敬。”\n“不过他官升三级也是众望所归。在大家看来，他是一个才华横溢的人。”\n“才华？一派鬼话！他这个人愚蠢至极。他给你一种印象，让你以为他做起事来精明强干、手到擒来。但如果是真的如此那才怪呢。他跟一个欧亚混血的普通小职员没有两样，什么事儿都得按部就班拼命应付。”\n“他何以赢得英明聪慧的名声？”\n“\n这个世界上有足够多的傻瓜。当一个官居高位的人对他们不摆架子，还拍拍他们的肩膀说他会为他们力尽所能，他们想当然以为此人智慧非凡\n。当然了，这里面也不能少了他夫人的份儿。她是个不同凡响的女人，颇有脑子，她的点子永远值得一用。有了她在后面拿主意，查理·唐生不用担心会做出蠢事来，而这正是在官场上顺风顺水的要务所在。政府不需要聪明的人，聪明的人有主见，而主见就是麻烦。他们要的是亲和、圆滑、永不犯愚蠢错误的人。嗯，不错，查理终将爬到这个金字塔的塔顶。”', metadata={'author': '【英】毛姆', 'tags': '小说', 'name': '面纱 【英】毛姆', 'id': '63ebcf03-6b91-48a0-b607-e83bcc9bbff4', 'source': '读书笔记（文学）', 'date_start': 20170906})]

# %%
from my_notion_companion.retriever import RetrieverEvaluator

with open('../.config.toml', 'rb') as f:
    _CONFIGS = tomllib.load(f)

re = RetrieverEvaluator(_CONFIGS)

# %%
# %%time

scores_bm25 = re.evaluate(retriever_bm25)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.89 ms /    22 runs   (    0.09 ms per token, 11664.90 tokens per second)
# llama_print_timings: prompt eval time =     498.68 ms /    45 tokens (   11.08 ms per token,    90.24 tokens per second)
# llama_print_timings:        eval time =     738.67 ms /    21 runs   (   35.17 ms per token,    28.43 tokens per second)
# llama_print_timings:       total time =    1272.51 ms /    66 tokens
# 2024-03-04 20:01:11.048 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['我国第一部编年史著作']
# search domains:['无']
# 2024-03-04 20:01:11.049 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.96 ms /    23 runs   (    0.09 ms per token, 11722.73 tokens per second)
# llama_print_timings: prompt eval time =     324.84 ms /    45 tokens (    7.22 ms per token,   138.53 tokens per second)
# llama_print_timings:        eval time =     779.02 ms /    22 runs   (   35.41 ms per token,    28.24 tokens per second)
# llama_print_timings:       total time =    1138.95 ms /    67 tokens
# 2024-03-04 20:01:13.264 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['第一部编年史', '国别史']
# search domains:['我国']
# 2024-03-04 20:01:13.264 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['我国']
# 2024-03-04 20:01:13.845 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.70 ms /    20 runs   (    0.08 ms per token, 11785.50 tokens per second)
# llama_print_timings: prompt eval time =     470.63 ms /    53 tokens (    8.88 ms per token,   112.62 tokens per second)
# llama_print_timings:        eval time =     672.34 ms /    19 runs   (   35.39 ms per token,    28.26 tokens per second)
# llama_print_timings:       total time =    1175.71 ms /    72 tokens
# 2024-03-04 20:01:17.103 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['寡人之于国也']
# search domains:['无']
# 2024-03-04 20:01:17.103 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.73 ms /    20 runs   (    0.09 ms per token, 11540.68 tokens per second)
# llama_print_timings: prompt eval time =     336.36 ms /    61 tokens (    5.51 ms per token,   181.35 tokens per second)
# llama_print_timings:        eval time =     676.25 ms /    19 runs   (   35.59 ms per token,    28.10 tokens per second)
# llama_print_timings:       total time =    1045.71 ms /    80 tokens
# 2024-03-04 20:01:19.238 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['庄子']
# search domains:['高中古诗文']
# 2024-03-04 20:01:19.238 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:01:19.263 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.029
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.00 ms /    23 runs   (    0.09 ms per token, 11494.25 tokens per second)
# llama_print_timings: prompt eval time =     328.49 ms /    57 tokens (    5.76 ms per token,   173.52 tokens per second)
# llama_print_timings:        eval time =     787.44 ms /    22 runs   (   35.79 ms per token,    27.94 tokens per second)
# llama_print_timings:       total time =    1154.77 ms /    79 tokens
# 2024-03-04 20:01:20.575 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['一陂春水绕花身']
# search domains:['搜索范scope：无']
# 2024-03-04 20:01:20.575 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['搜索范scope：无']
# 2024-03-04 20:01:20.596 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.10 ms /    37 runs   (    0.08 ms per token, 11920.10 tokens per second)
# llama_print_timings: prompt eval time =     564.76 ms /    79 tokens (    7.15 ms per token,   139.88 tokens per second)
# llama_print_timings:        eval time =    1303.91 ms /    36 runs   (   36.22 ms per token,    27.61 tokens per second)
# llama_print_timings:       total time =    1929.49 ms /   115 tokens
# 2024-03-04 20:01:23.633 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['此地有崇山峻岭茂林修竹']
# search domains:['高中古诗文']
# 2024-03-04 20:01:23.633 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:01:23.651 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.029
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.19 ms /    26 runs   (    0.08 ms per token, 11845.10 tokens per second)
# llama_print_timings: prompt eval time =     326.05 ms /    48 tokens (    6.79 ms per token,   147.21 tokens per second)
# llama_print_timings:        eval time =     905.28 ms /    25 runs   (   36.21 ms per token,    27.62 tokens per second)
# llama_print_timings:       total time =    1276.04 ms /    73 tokens
# 2024-03-04 20:01:25.081 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['苏轼', '韩愈', '评价']
# search domains:['无']
# 2024-03-04 20:01:25.081 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.96 ms /    23 runs   (    0.09 ms per token, 11728.71 tokens per second)
# llama_print_timings: prompt eval time =     425.81 ms /    51 tokens (    8.35 ms per token,   119.77 tokens per second)
# llama_print_timings:        eval time =     799.31 ms /    22 runs   (   36.33 ms per token,    27.52 tokens per second)
# llama_print_timings:       total time =    1261.93 ms /    73 tokens
# 2024-03-04 20:01:29.381 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['治大国若烹小鲜']
# search domains:['无']
# 2024-03-04 20:01:29.381 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.89 ms /    21 runs   (    0.09 ms per token, 11122.88 tokens per second)
# llama_print_timings: prompt eval time =     440.94 ms /    52 tokens (    8.48 ms per token,   117.93 tokens per second)
# llama_print_timings:        eval time =     742.77 ms /    20 runs   (   37.14 ms per token,    26.93 tokens per second)
# llama_print_timings:       total time =    1220.81 ms /    72 tokens
# 2024-03-04 20:01:31.724 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['卫风•氓', '修改']
# search domains:['无']
# 2024-03-04 20:01:31.725 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.22 ms /    15 runs   (    0.08 ms per token, 12335.53 tokens per second)
# llama_print_timings: prompt eval time =     456.76 ms /    44 tokens (   10.38 ms per token,    96.33 tokens per second)
# llama_print_timings:        eval time =     513.94 ms /    14 runs   (   36.71 ms per token,    27.24 tokens per second)
# llama_print_timings:       total time =     995.93 ms /    58 tokens
# 2024-03-04 20:01:34.954 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['短歌行']
# search domains:['无']
# 2024-03-04 20:01:34.954 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.86 ms /    23 runs   (    0.08 ms per token, 12332.44 tokens per second)
# llama_print_timings: prompt eval time =     395.62 ms /    59 tokens (    6.71 ms per token,   149.13 tokens per second)
# llama_print_timings:        eval time =     808.55 ms /    22 runs   (   36.75 ms per token,    27.21 tokens per second)
# llama_print_timings:       total time =    1243.22 ms /    81 tokens
# 2024-03-04 20:01:37.319 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['春江花月夜']
# search domains:['高中古诗文']
# 2024-03-04 20:01:37.319 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:01:37.338 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.029
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.43 ms /    39 runs   (    0.09 ms per token, 11363.64 tokens per second)
# llama_print_timings: prompt eval time =     335.14 ms /    64 tokens (    5.24 ms per token,   190.97 tokens per second)
# llama_print_timings:        eval time =    1407.77 ms /    38 runs   (   37.05 ms per token,    26.99 tokens per second)
# llama_print_timings:       total time =    1809.85 ms /   102 tokens
# 2024-03-04 20:01:39.322 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['黄州快哉亭记', '宋玉', '讽刺楚襄王']
# search domains:['无']
# 2024-03-04 20:01:39.322 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.40 ms /    27 runs   (    0.09 ms per token, 11231.28 tokens per second)
# llama_print_timings: prompt eval time =     437.50 ms /    54 tokens (    8.10 ms per token,   123.43 tokens per second)
# llama_print_timings:        eval time =     965.67 ms /    26 runs   (   37.14 ms per token,    26.92 tokens per second)
# llama_print_timings:       total time =    1447.38 ms /    80 tokens
# 2024-03-04 20:01:43.876 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['李白', '逍遥游']
# search domains:['古代诗歌']
# 2024-03-04 20:01:43.876 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['古代诗歌']
# 2024-03-04 20:01:43.894 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.022
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.28 ms /    27 runs   (    0.08 ms per token, 11836.91 tokens per second)
# llama_print_timings: prompt eval time =     454.78 ms /    68 tokens (    6.69 ms per token,   149.52 tokens per second)
# llama_print_timings:        eval time =     971.35 ms /    26 runs   (   37.36 ms per token,    26.77 tokens per second)
# llama_print_timings:       total time =    1471.79 ms /    94 tokens
# 2024-03-04 20:01:45.551 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['美的一次性']
# search domains:['小说', '读书笔记（文学）']
# 2024-03-04 20:01:45.551 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说', '读书笔记（文学）']
# 2024-03-04 20:01:45.585 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.540
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.54 ms /    30 runs   (    0.08 ms per token, 11787.82 tokens per second)
# llama_print_timings: prompt eval time =     462.28 ms /    67 tokens (    6.90 ms per token,   144.94 tokens per second)
# llama_print_timings:        eval time =    1092.80 ms /    29 runs   (   37.68 ms per token,    26.54 tokens per second)
# llama_print_timings:       total time =    1603.96 ms /    96 tokens
# 2024-03-04 20:01:47.851 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['我们之所以突然变得残暴']
# search domains:['三岛由纪夫', '小说']
# 2024-03-04 20:01:47.851 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['三岛由纪夫', '小说']
# 2024-03-04 20:01:47.882 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.329
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.61 ms /    32 runs   (    0.08 ms per token, 12269.94 tokens per second)
# llama_print_timings: prompt eval time =     467.11 ms /    77 tokens (    6.07 ms per token,   164.84 tokens per second)
# llama_print_timings:        eval time =    1176.75 ms /    31 runs   (   37.96 ms per token,    26.34 tokens per second)
# llama_print_timings:       total time =    1695.33 ms /   108 tokens
# 2024-03-04 20:01:50.024 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['每个人都以为他自己至少有一种主要的美德。']
# search domains:['无']
# 2024-03-04 20:01:50.025 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.94 ms /    33 runs   (    0.09 ms per token, 11239.78 tokens per second)
# llama_print_timings: prompt eval time =     472.42 ms /    81 tokens (    5.83 ms per token,   171.46 tokens per second)
# llama_print_timings:        eval time =    1221.62 ms /    32 runs   (   38.18 ms per token,    26.19 tokens per second)
# llama_print_timings:       total time =    1747.47 ms /   113 tokens
# 2024-03-04 20:01:52.858 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['钱钟书', '说“忠厚老实人的恶毒”']
# search domains:['无']
# 2024-03-04 20:01:52.858 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.16 ms /    24 runs   (    0.09 ms per token, 11116.26 tokens per second)
# llama_print_timings: prompt eval time =     568.33 ms /    82 tokens (    6.93 ms per token,   144.28 tokens per second)
# llama_print_timings:        eval time =     883.92 ms /    23 runs   (   38.43 ms per token,    26.02 tokens per second)
# llama_print_timings:       total time =    1492.40 ms /   105 tokens
# 2024-03-04 20:01:56.409 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['受迫害者和迫害者']
# search domains:['无']
# 2024-03-04 20:01:56.409 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.28 ms /    16 runs   (    0.08 ms per token, 12451.36 tokens per second)
# llama_print_timings: prompt eval time =     486.34 ms /    45 tokens (   10.81 ms per token,    92.53 tokens per second)
# llama_print_timings:        eval time =     578.06 ms /    15 runs   (   38.54 ms per token,    25.95 tokens per second)
# llama_print_timings:       total time =    1091.70 ms /    60 tokens
# 2024-03-04 20:01:58.579 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['细密画']
# search domains:['小说']
# 2024-03-04 20:01:58.579 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说']
# 2024-03-04 20:01:58.594 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.329
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.58 ms /    30 runs   (    0.09 ms per token, 11641.44 tokens per second)
# llama_print_timings: prompt eval time =     466.55 ms /    70 tokens (    6.67 ms per token,   150.04 tokens per second)
# llama_print_timings:        eval time =    1123.13 ms /    29 runs   (   38.73 ms per token,    25.82 tokens per second)
# llama_print_timings:       total time =    1643.02 ms /    99 tokens
# 2024-03-04 20:02:00.702 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['火车代表黑夜与毁灭']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:02:00.702 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:02:00.722 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.540
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.81 ms /    21 runs   (    0.09 ms per token, 11608.62 tokens per second)
# llama_print_timings: prompt eval time =     341.73 ms /    51 tokens (    6.70 ms per token,   149.24 tokens per second)
# llama_print_timings:        eval time =     779.50 ms /    20 runs   (   38.98 ms per token,    25.66 tokens per second)
# llama_print_timings:       total time =    1158.50 ms /    71 tokens
# 2024-03-04 20:02:02.544 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['天使与昆虫']
# search domains:['无']
# 2024-03-04 20:02:02.544 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.12 ms /    23 runs   (    0.09 ms per token, 10833.73 tokens per second)
# llama_print_timings: prompt eval time =     343.51 ms /    58 tokens (    5.92 ms per token,   168.85 tokens per second)
# llama_print_timings:        eval time =     859.11 ms /    22 runs   (   39.05 ms per token,    25.61 tokens per second)
# llama_print_timings:       total time =    1242.72 ms /    80 tokens
# 2024-03-04 20:02:04.865 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['雪']
# search domains:['辛波斯卡的诗歌']
# 2024-03-04 20:02:04.865 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['辛波斯卡的诗歌']
# 2024-03-04 20:02:04.885 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.022
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.21 ms /    26 runs   (    0.09 ms per token, 11738.15 tokens per second)
# llama_print_timings: prompt eval time =     335.69 ms /    58 tokens (    5.79 ms per token,   172.78 tokens per second)
# llama_print_timings:        eval time =     981.14 ms /    25 runs   (   39.25 ms per token,    25.48 tokens per second)
# llama_print_timings:       total time =    1364.45 ms /    83 tokens
# 2024-03-04 20:02:06.407 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['铁如意，指挥倜傥']
# search domains:['无']
# 2024-03-04 20:02:06.407 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.53 ms /    17 runs   (    0.09 ms per token, 11096.61 tokens per second)
# llama_print_timings: prompt eval time =     450.61 ms /    43 tokens (   10.48 ms per token,    95.43 tokens per second)
# llama_print_timings:        eval time =     630.08 ms /    16 runs   (   39.38 ms per token,    25.39 tokens per second)
# llama_print_timings:       total time =    1112.40 ms /    59 tokens
# 2024-03-04 20:02:08.708 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['四不捡']
# search domains:['无']
# 2024-03-04 20:02:08.709 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.93 ms /    22 runs   (    0.09 ms per token, 11387.16 tokens per second)
# llama_print_timings: prompt eval time =     339.86 ms /    51 tokens (    6.66 ms per token,   150.06 tokens per second)
# llama_print_timings:        eval time =     830.07 ms /    21 runs   (   39.53 ms per token,    25.30 tokens per second)
# llama_print_timings:       total time =    1209.75 ms /    72 tokens
# 2024-03-04 20:02:10.991 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['春天，十个海子']
# search domains:['海子全文']
# 2024-03-04 20:02:10.991 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['海子全文']
# 2024-03-04 20:02:11.010 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.001
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.26 ms /    25 runs   (    0.09 ms per token, 11047.28 tokens per second)
# llama_print_timings: prompt eval time =     369.47 ms /    45 tokens (    8.21 ms per token,   121.80 tokens per second)
# llama_print_timings:        eval time =     951.89 ms /    24 runs   (   39.66 ms per token,    25.21 tokens per second)
# llama_print_timings:       total time =    1367.32 ms /    69 tokens
# 2024-03-04 20:02:12.509 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['本多是哪本小说中出现的人物']
# search domains:['无']
# 2024-03-04 20:02:12.510 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.99 ms /    22 runs   (    0.09 ms per token, 11055.28 tokens per second)
# llama_print_timings: prompt eval time =     341.74 ms /    55 tokens (    6.21 ms per token,   160.94 tokens per second)
# llama_print_timings:        eval time =     836.57 ms /    21 runs   (   39.84 ms per token,    25.10 tokens per second)
# llama_print_timings:       total time =    1216.25 ms /    76 tokens
# 2024-03-04 20:02:14.804 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['接受神的恩惠降生的人']
# search domains:['无']
# 2024-03-04 20:02:14.805 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.97 ms /    23 runs   (    0.09 ms per token, 11657.37 tokens per second)
# llama_print_timings: prompt eval time =     393.87 ms /    55 tokens (    7.16 ms per token,   139.64 tokens per second)
# llama_print_timings:        eval time =     880.09 ms /    22 runs   (   40.00 ms per token,    25.00 tokens per second)
# llama_print_timings:       total time =    1313.61 ms /    77 tokens
# 2024-03-04 20:02:17.213 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['西伯利亚癔病']
# search domains:['小说']
# 2024-03-04 20:02:17.213 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说']
# 2024-03-04 20:02:17.226 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.329
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.16 ms /    25 runs   (    0.09 ms per token, 11600.93 tokens per second)
# llama_print_timings: prompt eval time =     467.71 ms /    67 tokens (    6.98 ms per token,   143.25 tokens per second)
# llama_print_timings:        eval time =     964.86 ms /    24 runs   (   40.20 ms per token,    24.87 tokens per second)
# llama_print_timings:       total time =    1475.82 ms /    91 tokens
# 2024-03-04 20:02:19.164 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['深秋初冬']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:02:19.164 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:02:19.185 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.540
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.45 ms /    39 runs   (    0.09 ms per token, 11317.47 tokens per second)
# llama_print_timings: prompt eval time =     344.66 ms /    60 tokens (    5.74 ms per token,   174.08 tokens per second)
# llama_print_timings:        eval time =    1537.60 ms /    38 runs   (   40.46 ms per token,    24.71 tokens per second)
# llama_print_timings:       total time =    1951.82 ms /    98 tokens
# 2024-03-04 20:02:21.825 | ERROR    | my_notion_companion.retriever:invoke:117 - Failed to construct query for the input: 请摘录“猛忆西湖，当年一梦难忘”的全诗词。, returning raw input.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.55 ms /    29 runs   (    0.09 ms per token, 11359.19 tokens per second)
# llama_print_timings: prompt eval time =     343.12 ms /    56 tokens (    6.13 ms per token,   163.21 tokens per second)
# llama_print_timings:        eval time =    1134.86 ms /    28 runs   (   40.53 ms per token,    24.67 tokens per second)
# llama_print_timings:       total time =    1530.29 ms /    84 tokens
# 2024-03-04 20:02:24.442 | ERROR    | my_notion_companion.retriever:invoke:117 - Failed to construct query for the input: “胁肩媚笑，病于夏畦”是什么意思？, returning raw input.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.51 ms /    30 runs   (    0.08 ms per token, 11947.43 tokens per second)
# llama_print_timings: prompt eval time =     443.22 ms /    56 tokens (    7.91 ms per token,   126.35 tokens per second)
# llama_print_timings:        eval time =    1180.01 ms /    29 runs   (   40.69 ms per token,    24.58 tokens per second)
# llama_print_timings:       total time =    1677.57 ms /    85 tokens
# 2024-03-04 20:02:27.212 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['道连·葛雷的画像、王尔德、形容英国人']
# search domains:['无']
# 2024-03-04 20:02:27.212 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.63 ms /    19 runs   (    0.09 ms per token, 11649.29 tokens per second)
# llama_print_timings: prompt eval time =     445.42 ms /    47 tokens (    9.48 ms per token,   105.52 tokens per second)
# llama_print_timings:        eval time =     735.16 ms /    18 runs   (   40.84 ms per token,    24.48 tokens per second)
# llama_print_timings:       total time =    1216.58 ms /    65 tokens
# 2024-03-04 20:02:29.523 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['子非吾友也']
# search domains:['无']
# 2024-03-04 20:02:29.523 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.50 ms /    30 runs   (    0.08 ms per token, 11985.62 tokens per second)
# llama_print_timings: prompt eval time =     435.01 ms /    49 tokens (    8.88 ms per token,   112.64 tokens per second)
# llama_print_timings:        eval time =    1188.33 ms /    29 runs   (   40.98 ms per token,    24.40 tokens per second)
# llama_print_timings:       total time =    1675.39 ms /    78 tokens
# 2024-03-04 20:02:32.324 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['昆德拉', '纽约']
# search domains:['小说', '摘抄']
# 2024-03-04 20:02:32.324 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说', '摘抄']
# 2024-03-04 20:02:32.356 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.330
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.30 ms /    37 runs   (    0.09 ms per token, 11198.55 tokens per second)
# llama_print_timings: prompt eval time =     478.04 ms /    79 tokens (    6.05 ms per token,   165.26 tokens per second)
# llama_print_timings:        eval time =    1484.89 ms /    36 runs   (   41.25 ms per token,    24.24 tokens per second)
# llama_print_timings:       total time =    2029.79 ms /   115 tokens
# 2024-03-04 20:02:35.199 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['某一天、某个人、天空中所有云朵的形状、与他相似']
# search domains:['无']
# 2024-03-04 20:02:35.199 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.17 ms /    36 runs   (    0.09 ms per token, 11345.73 tokens per second)
# llama_print_timings: prompt eval time =     480.44 ms /    78 tokens (    6.16 ms per token,   162.35 tokens per second)
# llama_print_timings:        eval time =    1452.08 ms /    35 runs   (   41.49 ms per token,    24.10 tokens per second)
# llama_print_timings:       total time =    1994.69 ms /   113 tokens
# 2024-03-04 20:02:38.314 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['有人把国家带进沟里，但这些人说统治是一门艺术']
# search domains:['无']
# 2024-03-04 20:02:38.315 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.52 ms /    29 runs   (    0.09 ms per token, 11512.50 tokens per second)
# llama_print_timings: prompt eval time =     474.75 ms /    63 tokens (    7.54 ms per token,   132.70 tokens per second)
# llama_print_timings:        eval time =    1167.46 ms /    28 runs   (   41.70 ms per token,    23.98 tokens per second)
# llama_print_timings:       total time =    1694.00 ms /    91 tokens
# 2024-03-04 20:02:41.146 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['心学和理学的区别']
# search domains:['《中国哲学简史》']
# 2024-03-04 20:02:41.146 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['《中国哲学简史》']
# 2024-03-04 20:02:41.168 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:71 - Remaining doc:  0.006
# 2024-03-04 20:02:41.178 | INFO     | my_notion_companion.retriever:evaluate:346 - Test cases pass rate: 0.469
# CPU times: user 48.4 s, sys: 1.57 s, total: 50 s
# Wall time: 1min 31s

# %%
# %%time

scores_bm25 = re.evaluate(retriever_bm25)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.90 ms /    22 runs   (    0.09 ms per token, 11603.38 tokens per second)
# llama_print_timings: prompt eval time =     467.25 ms /    45 tokens (   10.38 ms per token,    96.31 tokens per second)
# llama_print_timings:        eval time =     757.29 ms /    21 runs   (   36.06 ms per token,    27.73 tokens per second)
# llama_print_timings:       total time =    1264.24 ms /    66 tokens
# 2024-03-04 20:10:14.474 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['我国第一部编年史著作']
# search domains:['无']
# 2024-03-04 20:10:14.474 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.00 ms /    23 runs   (    0.09 ms per token, 11494.25 tokens per second)
# llama_print_timings: prompt eval time =     481.37 ms /    45 tokens (   10.70 ms per token,    93.48 tokens per second)
# llama_print_timings:        eval time =     796.07 ms /    22 runs   (   36.18 ms per token,    27.64 tokens per second)
# llama_print_timings:       total time =    1316.25 ms /    67 tokens
# 2024-03-04 20:10:16.858 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['第一部编年史', '国别史']
# search domains:['我国']
# 2024-03-04 20:10:16.859 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['我国']
# 2024-03-04 20:10:16.877 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.71 ms /    20 runs   (    0.09 ms per token, 11723.33 tokens per second)
# llama_print_timings: prompt eval time =     434.48 ms /    53 tokens (    8.20 ms per token,   121.99 tokens per second)
# llama_print_timings:        eval time =     691.73 ms /    19 runs   (   36.41 ms per token,    27.47 tokens per second)
# llama_print_timings:       total time =    1161.01 ms /    72 tokens
# 2024-03-04 20:10:20.073 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['寡人之于国也']
# search domains:['无']
# 2024-03-04 20:10:20.073 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.74 ms /    20 runs   (    0.09 ms per token, 11520.74 tokens per second)
# llama_print_timings: prompt eval time =     433.06 ms /    61 tokens (    7.10 ms per token,   140.86 tokens per second)
# llama_print_timings:        eval time =     700.94 ms /    19 runs   (   36.89 ms per token,    27.11 tokens per second)
# llama_print_timings:       total time =    1167.82 ms /    80 tokens
# 2024-03-04 20:10:22.459 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['庄子']
# search domains:['高中古诗文']
# 2024-03-04 20:10:22.459 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:10:22.478 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.94 ms /    23 runs   (    0.08 ms per token, 11855.67 tokens per second)
# llama_print_timings: prompt eval time =     328.42 ms /    57 tokens (    5.76 ms per token,   173.56 tokens per second)
# llama_print_timings:        eval time =     805.43 ms /    22 runs   (   36.61 ms per token,    27.31 tokens per second)
# llama_print_timings:       total time =    1172.81 ms /    79 tokens
# 2024-03-04 20:10:23.780 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['一陂春水绕花身']
# search domains:['搜索范scope：无']
# 2024-03-04 20:10:23.781 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['搜索范scope：无']
# 2024-03-04 20:10:23.801 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.15 ms /    37 runs   (    0.09 ms per token, 11742.30 tokens per second)
# llama_print_timings: prompt eval time =     595.14 ms /    79 tokens (    7.53 ms per token,   132.74 tokens per second)
# llama_print_timings:        eval time =    1330.14 ms /    36 runs   (   36.95 ms per token,    27.06 tokens per second)
# llama_print_timings:       total time =    1984.49 ms /   115 tokens
# 2024-03-04 20:10:26.904 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['此地有崇山峻岭茂林修竹']
# search domains:['高中古诗文']
# 2024-03-04 20:10:26.905 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:10:26.923 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.26 ms /    26 runs   (    0.09 ms per token, 11494.25 tokens per second)
# llama_print_timings: prompt eval time =     325.84 ms /    48 tokens (    6.79 ms per token,   147.31 tokens per second)
# llama_print_timings:        eval time =     925.76 ms /    25 runs   (   37.03 ms per token,    27.00 tokens per second)
# llama_print_timings:       total time =    1295.30 ms /    73 tokens
# 2024-03-04 20:10:28.345 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['苏轼', '韩愈', '评价']
# search domains:['无']
# 2024-03-04 20:10:28.345 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.98 ms /    23 runs   (    0.09 ms per token, 11616.16 tokens per second)
# llama_print_timings: prompt eval time =     427.25 ms /    51 tokens (    8.38 ms per token,   119.37 tokens per second)
# llama_print_timings:        eval time =     818.22 ms /    22 runs   (   37.19 ms per token,    26.89 tokens per second)
# llama_print_timings:       total time =    1283.32 ms /    73 tokens
# 2024-03-04 20:10:32.693 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['治大国若烹小鲜']
# search domains:['无']
# 2024-03-04 20:10:32.694 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.97 ms /    23 runs   (    0.09 ms per token, 11698.88 tokens per second)
# llama_print_timings: prompt eval time =     424.11 ms /    52 tokens (    8.16 ms per token,   122.61 tokens per second)
# llama_print_timings:        eval time =     821.56 ms /    22 runs   (   37.34 ms per token,    26.78 tokens per second)
# llama_print_timings:       total time =    1285.48 ms /    74 tokens
# 2024-03-04 20:10:35.050 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['《卫风•氓》', '修改']
# search domains:['无']
# 2024-03-04 20:10:35.050 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.59 ms /    19 runs   (    0.08 ms per token, 11927.18 tokens per second)
# llama_print_timings: prompt eval time =     434.58 ms /    44 tokens (    9.88 ms per token,   101.25 tokens per second)
# llama_print_timings:        eval time =     673.70 ms /    18 runs   (   37.43 ms per token,    26.72 tokens per second)
# llama_print_timings:       total time =    1141.20 ms /    62 tokens
# 2024-03-04 20:10:38.227 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['短歌行', '前两句']
# search domains:['无']
# 2024-03-04 20:10:38.228 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.05 ms /    23 runs   (    0.09 ms per token, 11235.96 tokens per second)
# llama_print_timings: prompt eval time =     441.55 ms /    59 tokens (    7.48 ms per token,   133.62 tokens per second)
# llama_print_timings:        eval time =     828.22 ms /    22 runs   (   37.65 ms per token,    26.56 tokens per second)
# llama_print_timings:       total time =    1310.53 ms /    81 tokens
# 2024-03-04 20:10:41.610 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['春江花月夜']
# search domains:['高中古诗文']
# 2024-03-04 20:10:41.610 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:10:41.629 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.69 ms /    45 runs   (    0.08 ms per token, 12211.67 tokens per second)
# llama_print_timings: prompt eval time =     329.04 ms /    64 tokens (    5.14 ms per token,   194.50 tokens per second)
# llama_print_timings:        eval time =    1668.53 ms /    44 runs   (   37.92 ms per token,    26.37 tokens per second)
# llama_print_timings:       total time =    2075.94 ms /   108 tokens
# 2024-03-04 20:10:43.842 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['黄州快哉亭记', '宋玉', '讽刺楚襄王']
# search domains:['高中古诗文']
# 2024-03-04 20:10:43.842 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:10:43.861 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.27 ms /    27 runs   (    0.08 ms per token, 11878.57 tokens per second)
# llama_print_timings: prompt eval time =     344.05 ms /    54 tokens (    6.37 ms per token,   156.96 tokens per second)
# llama_print_timings:        eval time =     986.65 ms /    26 runs   (   37.95 ms per token,    26.35 tokens per second)
# llama_print_timings:       total time =    1375.50 ms /    80 tokens
# 2024-03-04 20:10:45.401 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['李白', '逍遥游']
# search domains:['古代诗歌']
# 2024-03-04 20:10:45.401 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['古代诗歌']
# 2024-03-04 20:10:45.420 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.45 ms /    27 runs   (    0.09 ms per token, 11024.91 tokens per second)
# llama_print_timings: prompt eval time =     552.90 ms /    68 tokens (    8.13 ms per token,   122.99 tokens per second)
# llama_print_timings:        eval time =     994.74 ms /    26 runs   (   38.26 ms per token,    26.14 tokens per second)
# llama_print_timings:       total time =    1593.36 ms /    94 tokens
# 2024-03-04 20:10:49.061 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['美的一次性']
# search domains:['小说', '读书笔记（文学）']
# 2024-03-04 20:10:49.061 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说', '读书笔记（文学）']
# 2024-03-04 20:10:49.110 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.689
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.59 ms /    30 runs   (    0.09 ms per token, 11569.61 tokens per second)
# llama_print_timings: prompt eval time =     465.31 ms /    67 tokens (    6.94 ms per token,   143.99 tokens per second)
# llama_print_timings:        eval time =    1115.52 ms /    29 runs   (   38.47 ms per token,    26.00 tokens per second)
# llama_print_timings:       total time =    1631.42 ms /    96 tokens
# 2024-03-04 20:10:51.563 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['我们之所以突然变得残暴']
# search domains:['三岛由纪夫', '小说']
# 2024-03-04 20:10:51.564 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['三岛由纪夫', '小说']
# 2024-03-04 20:10:51.596 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.328
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.72 ms /    32 runs   (    0.09 ms per token, 11751.74 tokens per second)
# llama_print_timings: prompt eval time =     477.70 ms /    77 tokens (    6.20 ms per token,   161.19 tokens per second)
# llama_print_timings:        eval time =    1200.54 ms /    31 runs   (   38.73 ms per token,    25.82 tokens per second)
# llama_print_timings:       total time =    1732.96 ms /   108 tokens
# 2024-03-04 20:10:53.779 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['每个人都以为他自己至少有一种主要的美德。']
# search domains:['无']
# 2024-03-04 20:10:53.779 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.91 ms /    33 runs   (    0.09 ms per token, 11324.64 tokens per second)
# llama_print_timings: prompt eval time =     472.99 ms /    81 tokens (    5.84 ms per token,   171.25 tokens per second)
# llama_print_timings:        eval time =    1248.15 ms /    32 runs   (   39.00 ms per token,    25.64 tokens per second)
# llama_print_timings:       total time =    1778.74 ms /   113 tokens
# 2024-03-04 20:10:56.657 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['钱钟书', '说“忠厚老实人的恶毒”']
# search domains:['无']
# 2024-03-04 20:10:56.658 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.11 ms /    24 runs   (    0.09 ms per token, 11369.02 tokens per second)
# llama_print_timings: prompt eval time =     564.51 ms /    82 tokens (    6.88 ms per token,   145.26 tokens per second)
# llama_print_timings:        eval time =     902.52 ms /    23 runs   (   39.24 ms per token,    25.48 tokens per second)
# llama_print_timings:       total time =    1510.72 ms /   105 tokens
# 2024-03-04 20:11:00.285 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['受迫害者和迫害者']
# search domains:['无']
# 2024-03-04 20:11:00.285 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.44 ms /    16 runs   (    0.09 ms per token, 11095.70 tokens per second)
# llama_print_timings: prompt eval time =     337.15 ms /    45 tokens (    7.49 ms per token,   133.47 tokens per second)
# llama_print_timings:        eval time =     590.26 ms /    15 runs   (   39.35 ms per token,    25.41 tokens per second)
# llama_print_timings:       total time =     957.36 ms /    60 tokens
# 2024-03-04 20:11:02.323 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['细密画']
# search domains:['小说']
# 2024-03-04 20:11:02.324 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说']
# 2024-03-04 20:11:02.339 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.328
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.54 ms /    30 runs   (    0.08 ms per token, 11824.99 tokens per second)
# llama_print_timings: prompt eval time =     468.37 ms /    70 tokens (    6.69 ms per token,   149.45 tokens per second)
# llama_print_timings:        eval time =    1147.17 ms /    29 runs   (   39.56 ms per token,    25.28 tokens per second)
# llama_print_timings:       total time =    1667.54 ms /    99 tokens
# 2024-03-04 20:11:04.472 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['火车代表黑夜与毁灭']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:11:04.472 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:11:04.493 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.689
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.82 ms /    21 runs   (    0.09 ms per token, 11532.13 tokens per second)
# llama_print_timings: prompt eval time =     343.22 ms /    51 tokens (    6.73 ms per token,   148.59 tokens per second)
# llama_print_timings:        eval time =     795.75 ms /    20 runs   (   39.79 ms per token,    25.13 tokens per second)
# llama_print_timings:       total time =    1176.01 ms /    71 tokens
# 2024-03-04 20:11:06.477 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['天使与昆虫']
# search domains:['无']
# 2024-03-04 20:11:06.478 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.99 ms /    23 runs   (    0.09 ms per token, 11586.90 tokens per second)
# llama_print_timings: prompt eval time =     390.71 ms /    58 tokens (    6.74 ms per token,   148.45 tokens per second)
# llama_print_timings:        eval time =     879.16 ms /    22 runs   (   39.96 ms per token,    25.02 tokens per second)
# llama_print_timings:       total time =    1310.84 ms /    80 tokens
# 2024-03-04 20:11:08.861 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['雪']
# search domains:['辛波斯卡的诗歌']
# 2024-03-04 20:11:08.861 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['辛波斯卡的诗歌']
# 2024-03-04 20:11:08.881 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.19 ms /    26 runs   (    0.08 ms per token, 11888.43 tokens per second)
# llama_print_timings: prompt eval time =     353.90 ms /    58 tokens (    6.10 ms per token,   163.89 tokens per second)
# llama_print_timings:        eval time =    1002.49 ms /    25 runs   (   40.10 ms per token,    24.94 tokens per second)
# llama_print_timings:       total time =    1401.68 ms /    83 tokens
# 2024-03-04 20:11:11.421 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['铁如意，指挥倜傥']
# search domains:['无']
# 2024-03-04 20:11:11.421 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.42 ms /    17 runs   (    0.08 ms per token, 11980.27 tokens per second)
# llama_print_timings: prompt eval time =     339.72 ms /    43 tokens (    7.90 ms per token,   126.58 tokens per second)
# llama_print_timings:        eval time =     643.94 ms /    16 runs   (   40.25 ms per token,    24.85 tokens per second)
# llama_print_timings:       total time =    1015.13 ms /    59 tokens
# 2024-03-04 20:11:13.539 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['四不捡']
# search domains:['无']
# 2024-03-04 20:11:13.539 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.01 ms /    23 runs   (    0.09 ms per token, 11465.60 tokens per second)
# llama_print_timings: prompt eval time =     429.05 ms /    51 tokens (    8.41 ms per token,   118.87 tokens per second)
# llama_print_timings:        eval time =     887.10 ms /    22 runs   (   40.32 ms per token,    24.80 tokens per second)
# llama_print_timings:       total time =    1358.02 ms /    73 tokens
# 2024-03-04 20:11:15.988 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['春天，十个海子']
# search domains:['海子的作品']
# 2024-03-04 20:11:15.988 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['海子的作品']
# 2024-03-04 20:11:16.006 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.52 ms /    17 runs   (    0.09 ms per token, 11191.57 tokens per second)
# llama_print_timings: prompt eval time =     340.99 ms /    45 tokens (    7.58 ms per token,   131.97 tokens per second)
# llama_print_timings:        eval time =     647.97 ms /    16 runs   (   40.50 ms per token,    24.69 tokens per second)
# llama_print_timings:       total time =    1019.99 ms /    61 tokens
# 2024-03-04 20:11:18.131 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['本多', '小说']
# search domains:['无']
# 2024-03-04 20:11:18.131 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.98 ms /    22 runs   (    0.09 ms per token, 11127.97 tokens per second)
# llama_print_timings: prompt eval time =     446.96 ms /    55 tokens (    8.13 ms per token,   123.05 tokens per second)
# llama_print_timings:        eval time =     852.50 ms /    21 runs   (   40.60 ms per token,    24.63 tokens per second)
# llama_print_timings:       total time =    1340.75 ms /    76 tokens
# 2024-03-04 20:11:21.548 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['接受神的恩惠降生的人']
# search domains:['无']
# 2024-03-04 20:11:21.548 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.87 ms /    23 runs   (    0.08 ms per token, 12273.21 tokens per second)
# llama_print_timings: prompt eval time =     341.92 ms /    55 tokens (    6.22 ms per token,   160.86 tokens per second)
# llama_print_timings:        eval time =     896.12 ms /    22 runs   (   40.73 ms per token,    24.55 tokens per second)
# llama_print_timings:       total time =    1279.83 ms /    77 tokens
# 2024-03-04 20:11:23.922 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['西伯利亚癔病']
# search domains:['小说']
# 2024-03-04 20:11:23.923 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说']
# 2024-03-04 20:11:23.937 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.328
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.06 ms /    25 runs   (    0.08 ms per token, 12106.54 tokens per second)
# llama_print_timings: prompt eval time =     476.97 ms /    67 tokens (    7.12 ms per token,   140.47 tokens per second)
# llama_print_timings:        eval time =     984.97 ms /    24 runs   (   41.04 ms per token,    24.37 tokens per second)
# llama_print_timings:       total time =    1508.55 ms /    91 tokens
# 2024-03-04 20:11:25.922 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['深秋初冬']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:11:25.922 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:11:25.943 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.689
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.62 ms /    30 runs   (    0.09 ms per token, 11467.89 tokens per second)
# llama_print_timings: prompt eval time =     345.63 ms /    60 tokens (    5.76 ms per token,   173.60 tokens per second)
# llama_print_timings:        eval time =    1195.61 ms /    29 runs   (   41.23 ms per token,    24.26 tokens per second)
# llama_print_timings:       total time =    1596.53 ms /    89 tokens
# 2024-03-04 20:11:28.380 | ERROR    | my_notion_companion.retriever:invoke:117 - Failed to construct query for the input: 请摘录“猛忆西湖，当年一梦难忘”的全诗词。, returning raw input.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.34 ms /    29 runs   (    0.08 ms per token, 12393.16 tokens per second)
# llama_print_timings: prompt eval time =     350.62 ms /    56 tokens (    6.26 ms per token,   159.72 tokens per second)
# llama_print_timings:        eval time =    1158.58 ms /    28 runs   (   41.38 ms per token,    24.17 tokens per second)
# llama_print_timings:       total time =    1562.91 ms /    84 tokens
# 2024-03-04 20:11:31.032 | ERROR    | my_notion_companion.retriever:invoke:117 - Failed to construct query for the input: “胁肩媚笑，病于夏畦”是什么意思？, returning raw input.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.68 ms /    30 runs   (    0.09 ms per token, 11206.57 tokens per second)
# llama_print_timings: prompt eval time =     345.31 ms /    56 tokens (    6.17 ms per token,   162.17 tokens per second)
# llama_print_timings:        eval time =    1206.19 ms /    29 runs   (   41.59 ms per token,    24.04 tokens per second)
# llama_print_timings:       total time =    1605.13 ms /    85 tokens
# 2024-03-04 20:11:33.837 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['道连·葛雷的画像、王尔德、形容英国人']
# search domains:['无']
# 2024-03-04 20:11:33.837 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       1.67 ms /    19 runs   (    0.09 ms per token, 11404.56 tokens per second)
# llama_print_timings: prompt eval time =     338.14 ms /    47 tokens (    7.19 ms per token,   139.00 tokens per second)
# llama_print_timings:        eval time =     749.68 ms /    18 runs   (   41.65 ms per token,    24.01 tokens per second)
# llama_print_timings:       total time =    1123.31 ms /    65 tokens
# 2024-03-04 20:11:36.078 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['子非吾友也']
# search domains:['无']
# 2024-03-04 20:11:36.078 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.44 ms /    28 runs   (    0.09 ms per token, 11489.54 tokens per second)
# llama_print_timings: prompt eval time =     346.66 ms /    49 tokens (    7.07 ms per token,   141.35 tokens per second)
# llama_print_timings:        eval time =    1130.59 ms /    27 runs   (   41.87 ms per token,    23.88 tokens per second)
# llama_print_timings:       total time =    1528.50 ms /    76 tokens
# 2024-03-04 20:11:38.706 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['昆德拉', '纽约']
# search domains:['文章或书籍']
# 2024-03-04 20:11:38.706 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['文章或书籍']
# 2024-03-04 20:11:38.724 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.25 ms /    37 runs   (    0.09 ms per token, 11381.11 tokens per second)
# llama_print_timings: prompt eval time =     565.59 ms /    79 tokens (    7.16 ms per token,   139.68 tokens per second)
# llama_print_timings:        eval time =    1512.27 ms /    36 runs   (   42.01 ms per token,    23.81 tokens per second)
# llama_print_timings:       total time =    2144.76 ms /   115 tokens
# 2024-03-04 20:11:42.964 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['某一天', '某个人的生命中', '云朵的形状', '与', '他相似']
# search domains:['无']
# 2024-03-04 20:11:42.964 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.07 ms /    36 runs   (    0.09 ms per token, 11718.75 tokens per second)
# llama_print_timings: prompt eval time =     586.96 ms /    78 tokens (    7.53 ms per token,   132.89 tokens per second)
# llama_print_timings:        eval time =    1480.26 ms /    35 runs   (   42.29 ms per token,    23.64 tokens per second)
# llama_print_timings:       total time =    2133.02 ms /   113 tokens
# 2024-03-04 20:11:50.045 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['有人把国家带进沟里，但这些人说统治是一门艺术']
# search domains:['无']
# 2024-03-04 20:11:50.045 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       2.43 ms /    29 runs   (    0.08 ms per token, 11924.34 tokens per second)
# llama_print_timings: prompt eval time =     440.82 ms /    63 tokens (    7.00 ms per token,   142.92 tokens per second)
# llama_print_timings:        eval time =    1185.94 ms /    28 runs   (   42.35 ms per token,    23.61 tokens per second)
# llama_print_timings:       total time =    1679.06 ms /    91 tokens
# 2024-03-04 20:11:52.866 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['心学和理学的区别']
# search domains:['《中国哲学简史》']
# 2024-03-04 20:11:52.866 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['《中国哲学简史》']
# 2024-03-04 20:11:52.887 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:74 - Remaining doc:  0.006
# 2024-03-04 20:11:52.898 | INFO     | my_notion_companion.retriever:evaluate:346 - Test cases pass rate: 0.490
# CPU times: user 56.4 s, sys: 999 ms, total: 57.4 s
# Wall time: 1min 39s

# %%
# %%time

scores_bm25 = re.evaluate(retriever_bm25)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.86 ms /    21 runs   (    0.09 ms per token, 11266.09 tokens per second)
# llama_print_timings: prompt eval time =     453.32 ms /    45 tokens (   10.07 ms per token,    99.27 tokens per second)
# llama_print_timings:        eval time =     838.01 ms /    20 runs   (   41.90 ms per token,    23.87 tokens per second)
# llama_print_timings:       total time =    1328.58 ms /    65 tokens
# 2024-03-04 20:23:48.306 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['第一部编年史著作']
# search domains:['我国']
# 2024-03-04 20:23:48.307 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['我国']
# 2024-03-04 20:23:48.325 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.08 ms /    25 runs   (    0.08 ms per token, 11996.16 tokens per second)
# llama_print_timings: prompt eval time =     342.45 ms /    45 tokens (    7.61 ms per token,   131.41 tokens per second)
# llama_print_timings:        eval time =    1010.11 ms /    24 runs   (   42.09 ms per token,    23.76 tokens per second)
# llama_print_timings:       total time =    1396.98 ms /    69 tokens
# 2024-03-04 20:23:50.801 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['第一部编年史或编年国别史']
# search domains:['我国']
# 2024-03-04 20:23:50.801 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['我国']
# 2024-03-04 20:23:50.820 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       3.13 ms /    31 runs   (    0.10 ms per token,  9916.83 tokens per second)
# llama_print_timings: prompt eval time =     347.86 ms /    53 tokens (    6.56 ms per token,   152.36 tokens per second)
# llama_print_timings:        eval time =    1289.29 ms /    30 runs   (   42.98 ms per token,    23.27 tokens per second)
# llama_print_timings:       total time =    1702.39 ms /    83 tokens
# 2024-03-04 20:23:53.610 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['寡人之于国也']
# search domains:['《孔子》或者《论语》']
# 2024-03-04 20:23:53.610 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['《孔子》或者《论语》']
# 2024-03-04 20:23:53.631 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.47 ms /    27 runs   (    0.09 ms per token, 10944.47 tokens per second)
# llama_print_timings: prompt eval time =     503.82 ms /    61 tokens (    8.26 ms per token,   121.07 tokens per second)
# llama_print_timings:        eval time =    1102.08 ms /    26 runs   (   42.39 ms per token,    23.59 tokens per second)
# llama_print_timings:       total time =    1654.86 ms /    87 tokens
# 2024-03-04 20:23:56.373 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['庄子', '写过哪些文章']
# search domains:['高中古诗文']
# 2024-03-04 20:23:56.374 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:23:56.393 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.72 ms /    31 runs   (    0.09 ms per token, 11409.64 tokens per second)
# llama_print_timings: prompt eval time =     366.27 ms /    57 tokens (    6.43 ms per token,   155.62 tokens per second)
# llama_print_timings:        eval time =    1277.15 ms /    30 runs   (   42.57 ms per token,    23.49 tokens per second)
# llama_print_timings:       total time =    1701.24 ms /    87 tokens
# 2024-03-04 20:23:58.247 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['一陂春水绕花身']
# search domains:['汉语语法或汉语词典']
# 2024-03-04 20:23:58.247 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['汉语语法或汉语词典']
# 2024-03-04 20:23:58.267 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       3.15 ms /    37 runs   (    0.09 ms per token, 11760.97 tokens per second)
# llama_print_timings: prompt eval time =     557.54 ms /    79 tokens (    7.06 ms per token,   141.69 tokens per second)
# llama_print_timings:        eval time =    1544.56 ms /    36 runs   (   42.90 ms per token,    23.31 tokens per second)
# llama_print_timings:       total time =    2167.76 ms /   115 tokens
# 2024-03-04 20:24:01.515 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['此地有崇山峻岭茂林修竹']
# search domains:['高中古诗文']
# 2024-03-04 20:24:01.515 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:24:01.534 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.43 ms /    29 runs   (    0.08 ms per token, 11958.76 tokens per second)
# llama_print_timings: prompt eval time =     381.04 ms /    48 tokens (    7.94 ms per token,   125.97 tokens per second)
# llama_print_timings:        eval time =    1206.65 ms /    28 runs   (   43.09 ms per token,    23.20 tokens per second)
# llama_print_timings:       total time =    1643.23 ms /    76 tokens
# 2024-03-04 20:24:03.321 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['苏轼', '韩愈']
# search domains:['高中古诗文']
# 2024-03-04 20:24:03.321 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:24:03.339 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.17 ms /    23 runs   (    0.09 ms per token, 10608.86 tokens per second)
# llama_print_timings: prompt eval time =     353.14 ms /    51 tokens (    6.92 ms per token,   144.42 tokens per second)
# llama_print_timings:        eval time =     948.79 ms /    22 runs   (   43.13 ms per token,    23.19 tokens per second)
# llama_print_timings:       total time =    1346.12 ms /    73 tokens
# 2024-03-04 20:24:04.839 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['治大国若烹小鲜']
# search domains:['无']
# 2024-03-04 20:24:04.839 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =      22.12 ms /   256 runs   (    0.09 ms per token, 11575.33 tokens per second)
# llama_print_timings: prompt eval time =     435.19 ms /    52 tokens (    8.37 ms per token,   119.49 tokens per second)
# llama_print_timings:        eval time =   11196.82 ms /   255 runs   (   43.91 ms per token,    22.77 tokens per second)
# llama_print_timings:       total time =   12096.25 ms /   307 tokens
# 2024-03-04 20:24:18.052 | ERROR    | my_notion_companion.retriever:invoke:117 - Failed to construct query for the input: 据推测，《卫风•氓》是否没有经过修改？, returning raw input.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.18 ms /    25 runs   (    0.09 ms per token, 11494.25 tokens per second)
# llama_print_timings: prompt eval time =     344.55 ms /    44 tokens (    7.83 ms per token,   127.70 tokens per second)
# llama_print_timings:        eval time =    1041.69 ms /    24 runs   (   43.40 ms per token,    23.04 tokens per second)
# llama_print_timings:       total time =    1432.72 ms /    68 tokens
# 2024-03-04 20:24:20.578 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['短歌行', '前两句']
# search domains:['高中古诗文']
# 2024-03-04 20:24:20.578 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:24:20.596 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.98 ms /    23 runs   (    0.09 ms per token, 11639.68 tokens per second)
# llama_print_timings: prompt eval time =     384.33 ms /    59 tokens (    6.51 ms per token,   153.51 tokens per second)
# llama_print_timings:        eval time =     961.19 ms /    22 runs   (   43.69 ms per token,    22.89 tokens per second)
# llama_print_timings:       total time =    1390.80 ms /    81 tokens
# 2024-03-04 20:24:22.131 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['春江花月夜']
# search domains:['高中古诗文']
# 2024-03-04 20:24:22.132 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['高中古诗文']
# 2024-03-04 20:24:22.150 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.007
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       3.34 ms /    39 runs   (    0.09 ms per token, 11683.64 tokens per second)
# llama_print_timings: prompt eval time =     381.81 ms /    64 tokens (    5.97 ms per token,   167.62 tokens per second)
# llama_print_timings:        eval time =    1668.53 ms /    38 runs   (   43.91 ms per token,    22.77 tokens per second)
# llama_print_timings:       total time =    2122.57 ms /   102 tokens
# 2024-03-04 20:24:24.419 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['宋玉', '讽刺楚襄王']
# search domains:['《黄州快哉亭记》']
# 2024-03-04 20:24:24.420 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['《黄州快哉亭记》']
# 2024-03-04 20:24:24.442 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.82 ms /    22 runs   (    0.08 ms per token, 12068.02 tokens per second)
# llama_print_timings: prompt eval time =     465.77 ms /    54 tokens (    8.63 ms per token,   115.94 tokens per second)
# llama_print_timings:        eval time =     922.14 ms /    21 runs   (   43.91 ms per token,    22.77 tokens per second)
# llama_print_timings:       total time =    1428.63 ms /    75 tokens
# 2024-03-04 20:24:27.944 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['李白', '逍遥游']
# search domains:['无']
# 2024-03-04 20:24:27.944 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.06 ms /    24 runs   (    0.09 ms per token, 11656.14 tokens per second)
# llama_print_timings: prompt eval time =     590.16 ms /    68 tokens (    8.68 ms per token,   115.22 tokens per second)
# llama_print_timings:        eval time =    1015.55 ms /    23 runs   (   44.15 ms per token,    22.65 tokens per second)
# llama_print_timings:       total time =    1650.97 ms /    91 tokens
# 2024-03-04 20:24:31.745 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['美的一次性']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:24:31.745 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:24:31.765 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.689
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.52 ms /    30 runs   (    0.08 ms per token, 11904.76 tokens per second)
# llama_print_timings: prompt eval time =     486.98 ms /    67 tokens (    7.27 ms per token,   137.58 tokens per second)
# llama_print_timings:        eval time =    1286.34 ms /    29 runs   (   44.36 ms per token,    22.54 tokens per second)
# llama_print_timings:       total time =    1828.27 ms /    96 tokens
# 2024-03-04 20:24:34.422 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['我们之所以突然变得残暴']
# search domains:['三岛由纪夫的小说']
# 2024-03-04 20:24:34.423 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['三岛由纪夫的小说']
# 2024-03-04 20:24:34.445 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       3.31 ms /    38 runs   (    0.09 ms per token, 11497.73 tokens per second)
# llama_print_timings: prompt eval time =     489.08 ms /    77 tokens (    6.35 ms per token,   157.44 tokens per second)
# llama_print_timings:        eval time =    1652.71 ms /    37 runs   (   44.67 ms per token,    22.39 tokens per second)
# llama_print_timings:       total time =    2211.44 ms /   114 tokens
# 2024-03-04 20:24:37.735 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['每个人都以为他自己至少有一种主要的美德']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:24:37.735 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:24:37.755 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.689
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =      15.69 ms /   180 runs   (    0.09 ms per token, 11471.54 tokens per second)
# llama_print_timings: prompt eval time =     494.90 ms /    81 tokens (    6.11 ms per token,   163.67 tokens per second)
# llama_print_timings:        eval time =    8113.76 ms /   179 runs   (   45.33 ms per token,    22.06 tokens per second)
# llama_print_timings:       total time =    8938.26 ms /   260 tokens
# 2024-03-04 20:24:47.505 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['钱钟书', '忠厚老实人的恶毒']
# search domains:['文学作品或者相关文章']
# 2024-03-04 20:24:47.505 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['文学作品或者相关文章']
# 2024-03-04 20:24:47.525 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.38 ms /    28 runs   (    0.08 ms per token, 11774.60 tokens per second)
# llama_print_timings: prompt eval time =     591.28 ms /    82 tokens (    7.21 ms per token,   138.68 tokens per second)
# llama_print_timings:        eval time =    1221.25 ms /    27 runs   (   45.23 ms per token,    22.11 tokens per second)
# llama_print_timings:       total time =    1864.18 ms /   109 tokens
# 2024-03-04 20:24:51.478 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['昆德拉', '最悲愁的发现']
# search domains:['无']
# 2024-03-04 20:24:51.478 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.45 ms /    16 runs   (    0.09 ms per token, 11065.01 tokens per second)
# llama_print_timings: prompt eval time =     450.32 ms /    45 tokens (   10.01 ms per token,    99.93 tokens per second)
# llama_print_timings:        eval time =     680.12 ms /    15 runs   (   45.34 ms per token,    22.05 tokens per second)
# llama_print_timings:       total time =    1161.90 ms /    60 tokens
# 2024-03-04 20:24:54.715 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['细密画']
# search domains:['小说']
# 2024-03-04 20:24:54.715 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说']
# 2024-03-04 20:24:54.729 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.328
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.58 ms /    30 runs   (    0.09 ms per token, 11623.40 tokens per second)
# llama_print_timings: prompt eval time =     491.90 ms /    70 tokens (    7.03 ms per token,   142.31 tokens per second)
# llama_print_timings:        eval time =    1322.73 ms /    29 runs   (   45.61 ms per token,    21.92 tokens per second)
# llama_print_timings:       total time =    1870.28 ms /    99 tokens
# 2024-03-04 20:24:57.092 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['火车代表黑夜与毁灭']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:24:57.092 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:24:57.112 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.689
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.78 ms /    21 runs   (    0.08 ms per token, 11791.13 tokens per second)
# llama_print_timings: prompt eval time =     357.50 ms /    51 tokens (    7.01 ms per token,   142.66 tokens per second)
# llama_print_timings:        eval time =     914.91 ms /    20 runs   (   45.75 ms per token,    21.86 tokens per second)
# llama_print_timings:       total time =    1312.91 ms /    71 tokens
# 2024-03-04 20:24:59.236 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['天使与昆虫']
# search domains:['无']
# 2024-03-04 20:24:59.237 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.89 ms /    22 runs   (    0.09 ms per token, 11634.06 tokens per second)
# llama_print_timings: prompt eval time =     432.24 ms /    58 tokens (    7.45 ms per token,   134.19 tokens per second)
# llama_print_timings:        eval time =     964.53 ms /    21 runs   (   45.93 ms per token,    21.77 tokens per second)
# llama_print_timings:       total time =    1438.77 ms /    79 tokens
# 2024-03-04 20:25:01.777 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['雪']
# search domains:['辛波斯卡诗歌']
# 2024-03-04 20:25:01.777 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['辛波斯卡诗歌']
# 2024-03-04 20:25:01.798 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.21 ms /    26 runs   (    0.09 ms per token, 11738.15 tokens per second)
# llama_print_timings: prompt eval time =     463.85 ms /    58 tokens (    8.00 ms per token,   125.04 tokens per second)
# llama_print_timings:        eval time =    1152.91 ms /    25 runs   (   46.12 ms per token,    21.68 tokens per second)
# llama_print_timings:       total time =    1666.25 ms /    83 tokens
# 2024-03-04 20:25:04.543 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['铁如意，指挥倜傥']
# search domains:['无']
# 2024-03-04 20:25:04.543 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.42 ms /    17 runs   (    0.08 ms per token, 12005.65 tokens per second)
# llama_print_timings: prompt eval time =     472.05 ms /    43 tokens (   10.98 ms per token,    91.09 tokens per second)
# llama_print_timings:        eval time =     742.74 ms /    16 runs   (   46.42 ms per token,    21.54 tokens per second)
# llama_print_timings:       total time =    1248.82 ms /    59 tokens
# 2024-03-04 20:25:06.898 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['四不捡']
# search domains:['无']
# 2024-03-04 20:25:06.898 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =      22.19 ms /   256 runs   (    0.09 ms per token, 11536.73 tokens per second)
# llama_print_timings: prompt eval time =     425.38 ms /    51 tokens (    8.34 ms per token,   119.89 tokens per second)
# llama_print_timings:        eval time =   11956.15 ms /   255 runs   (   46.89 ms per token,    21.33 tokens per second)
# llama_print_timings:       total time =   12866.92 ms /   306 tokens
# 2024-03-04 20:25:20.867 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['春天、十个海子、海子']
# search domains:['无']
# 2024-03-04 20:25:20.867 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =      21.71 ms /   256 runs   (    0.08 ms per token, 11790.17 tokens per second)
# llama_print_timings: prompt eval time =     479.30 ms /    45 tokens (   10.65 ms per token,    93.89 tokens per second)
# llama_print_timings:        eval time =   12028.19 ms /   255 runs   (   47.17 ms per token,    21.20 tokens per second)
# llama_print_timings:       total time =   12983.95 ms /   300 tokens
# 2024-03-04 20:25:35.034 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['本多']
# search domains:['小说', '主角']
# 2024-03-04 20:25:35.034 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说', '主角']
# 2024-03-04 20:25:35.067 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.328
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.85 ms /    22 runs   (    0.08 ms per token, 11917.66 tokens per second)
# llama_print_timings: prompt eval time =     359.46 ms /    55 tokens (    6.54 ms per token,   153.01 tokens per second)
# llama_print_timings:        eval time =     979.51 ms /    21 runs   (   46.64 ms per token,    21.44 tokens per second)
# llama_print_timings:       total time =    1381.16 ms /    76 tokens
# 2024-03-04 20:25:36.938 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['接受神的恩惠降生的人']
# search domains:['无']
# 2024-03-04 20:25:36.938 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.98 ms /    23 runs   (    0.09 ms per token, 11598.59 tokens per second)
# llama_print_timings: prompt eval time =     363.33 ms /    55 tokens (    6.61 ms per token,   151.38 tokens per second)
# llama_print_timings:        eval time =    1030.80 ms /    22 runs   (   46.85 ms per token,    21.34 tokens per second)
# llama_print_timings:       total time =    1438.28 ms /    77 tokens
# 2024-03-04 20:25:39.509 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['西伯利亚癔病']
# search domains:['小说']
# 2024-03-04 20:25:39.509 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['小说']
# 2024-03-04 20:25:39.523 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.328
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.19 ms /    25 runs   (    0.09 ms per token, 11425.96 tokens per second)
# llama_print_timings: prompt eval time =     492.87 ms /    67 tokens (    7.36 ms per token,   135.94 tokens per second)
# llama_print_timings:        eval time =    1132.63 ms /    24 runs   (   47.19 ms per token,    21.19 tokens per second)
# llama_print_timings:       total time =    1672.90 ms /    91 tokens
# 2024-03-04 20:25:41.690 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['深秋初冬']
# search domains:['读书笔记（文学）']
# 2024-03-04 20:25:41.690 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['读书笔记（文学）']
# 2024-03-04 20:25:41.710 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.689
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =      21.90 ms /   256 runs   (    0.09 ms per token, 11687.90 tokens per second)
# llama_print_timings: prompt eval time =     359.72 ms /    60 tokens (    6.00 ms per token,   166.80 tokens per second)
# llama_print_timings:        eval time =   12176.61 ms /   255 runs   (   47.75 ms per token,    20.94 tokens per second)
# llama_print_timings:       total time =   13025.93 ms /   315 tokens
# 2024-03-04 20:25:55.564 | ERROR    | my_notion_companion.retriever:invoke:117 - Failed to construct query for the input: 请摘录“猛忆西湖，当年一梦难忘”的全诗词。, returning raw input.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =      21.61 ms /   256 runs   (    0.08 ms per token, 11848.01 tokens per second)
# llama_print_timings: prompt eval time =     444.20 ms /    56 tokens (    7.93 ms per token,   126.07 tokens per second)
# llama_print_timings:        eval time =   12248.46 ms /   255 runs   (   48.03 ms per token,    20.82 tokens per second)
# llama_print_timings:       total time =   13183.89 ms /   311 tokens
# 2024-03-04 20:26:09.897 | ERROR    | my_notion_companion.retriever:invoke:117 - Failed to construct query for the input: “胁肩媚笑，病于夏畦”是什么意思？, returning raw input.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.55 ms /    30 runs   (    0.08 ms per token, 11769.32 tokens per second)
# llama_print_timings: prompt eval time =     437.52 ms /    56 tokens (    7.81 ms per token,   127.99 tokens per second)
# llama_print_timings:        eval time =    1380.41 ms /    29 runs   (   47.60 ms per token,    21.01 tokens per second)
# llama_print_timings:       total time =    1874.61 ms /    85 tokens
# 2024-03-04 20:26:12.930 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['王尔德', '形容英国人']
# search domains:['《道连·葛雷的画像》']
# 2024-03-04 20:26:12.931 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['《道连·葛雷的画像》']
# 2024-03-04 20:26:12.950 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.62 ms /    19 runs   (    0.09 ms per token, 11735.64 tokens per second)
# llama_print_timings: prompt eval time =     456.37 ms /    47 tokens (    9.71 ms per token,   102.99 tokens per second)
# llama_print_timings:        eval time =     860.31 ms /    18 runs   (   47.79 ms per token,    20.92 tokens per second)
# llama_print_timings:       total time =    1354.62 ms /    65 tokens
# 2024-03-04 20:26:16.408 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['子非吾友也']
# search domains:['无']
# 2024-03-04 20:26:16.408 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       1.80 ms /    22 runs   (    0.08 ms per token, 12195.12 tokens per second)
# llama_print_timings: prompt eval time =     357.66 ms /    49 tokens (    7.30 ms per token,   137.00 tokens per second)
# llama_print_timings:        eval time =    1004.26 ms /    21 runs   (   47.82 ms per token,    20.91 tokens per second)
# llama_print_timings:       total time =    1404.60 ms /    70 tokens
# 2024-03-04 20:26:18.942 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['昆德拉', '纽约']
# search domains:['无']
# 2024-03-04 20:26:18.942 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       8.92 ms /   102 runs   (    0.09 ms per token, 11438.82 tokens per second)
# llama_print_timings: prompt eval time =     633.94 ms /    79 tokens (    8.02 ms per token,   124.62 tokens per second)
# llama_print_timings:        eval time =    4879.56 ms /   101 runs   (   48.31 ms per token,    20.70 tokens per second)
# llama_print_timings:       total time =    5703.94 ms /   180 tokens
# 2024-03-04 20:26:26.790 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['我相信某一天，在某个人的生命中，他头顶天空中所有云朵的形状将会片刻地与他相似']
# search domains:['文学作品、作者笔记、杂志文章等内容。如果无法确定出处，请回复并提供更多上下文或相似内容以帮助确定出处。']
# 2024-03-04 20:26:26.790 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['文学作品、作者笔记、杂志文章等内容。如果无法确定出处，请回复并提供更多上下文或相似内容以帮助确定出处。']
# 2024-03-04 20:26:26.829 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       3.12 ms /    36 runs   (    0.09 ms per token, 11556.98 tokens per second)
# llama_print_timings: prompt eval time =     574.58 ms /    78 tokens (    7.37 ms per token,   135.75 tokens per second)
# llama_print_timings:        eval time =    1696.00 ms /    35 runs   (   48.46 ms per token,    20.64 tokens per second)
# llama_print_timings:       total time =    2341.97 ms /   113 tokens
# 2024-03-04 20:26:30.334 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['有人把国家带进沟里，但这些人说统治是一门艺术']
# search domains:['无']
# 2024-03-04 20:26:30.334 | INFO     | my_notion_companion.retriever:_filter_documents:95 - No filters found by query analyzer.
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4103.62 ms
# llama_print_timings:      sample time =       2.74 ms /    29 runs   (    0.09 ms per token, 10595.54 tokens per second)
# llama_print_timings: prompt eval time =     462.43 ms /    63 tokens (    7.34 ms per token,   136.24 tokens per second)
# llama_print_timings:        eval time =    1360.39 ms /    28 runs   (   48.59 ms per token,    20.58 tokens per second)
# llama_print_timings:       total time =    1880.04 ms /    91 tokens
# 2024-03-04 20:26:33.477 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['心学和理学的区别']
# search domains:['《中国哲学简史》']
# 2024-03-04 20:26:33.477 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['《中国哲学简史》']
# 2024-03-04 20:26:33.499 | INFO     | my_notion_companion.document_filter:filter_multiple_criteria:75 - Remaining doc:  0.006
# 2024-03-04 20:26:33.508 | INFO     | my_notion_companion.retriever:evaluate:346 - Test cases pass rate: 0.449
# CPU times: user 1min 2s, sys: 1.79 s, total: 1min 3s
# Wall time: 2min 46s

# %%
retriever_bm25.invoke("我写过什么？来源在“特定来源”中")
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    4026.27 ms
# llama_print_timings:      sample time =       1.73 ms /    20 runs   (    0.09 ms per token, 11587.49 tokens per second)
# llama_print_timings: prompt eval time =     418.12 ms /    47 tokens (    8.90 ms per token,   112.41 tokens per second)
# llama_print_timings:        eval time =     685.68 ms /    19 runs   (   36.09 ms per token,    27.71 tokens per second)
# llama_print_timings:       total time =    1134.45 ms /    66 tokens
# 2024-03-04 16:37:46.755 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['我写过什么']
# search domains:['特定来源']
# 2024-03-04 16:37:46.755 | INFO     | my_notion_companion.retriever:_filter_documents:99 - filter found by query analyzer: ['特定来源']
# 2024-03-04 16:37:46.773 | INFO     | my_notion_companion.retriever:_filter_documents:103 - No matched doc found based on query analyzer. Search all docs.
# [Document(page_content='平叙到此，我又一次想起了一句撞击我灵魂深处的话语——\n我说人生啊,如果尝过一回痛快淋漓的风景,写过一篇杜鹃啼血的文章,与一个赏心悦目的人错肩，也就够了。', metadata={'author': '七堇年', 'tags': '散文', 'name': '被窝是青春的坟墓', 'id': 'fea8b1f5-3d81-438c-a718-41e03b10b9dc', 'source': '读书笔记（文学）', 'date_start': 20150930}),
#  Document(page_content='我说自己多年以来保持了沉默，你可能不信。这说明你是个过来人。你不信我从未在会议上“表过态”，也没写过批判稿。这种怀疑是对的：因为我既不能证明自己是哑巴，也不能证明自己不会写字，所以这两件事我都是干过的。但照我的标准，那不叫说话，而是上着一种\n话语的捐税\n。我们听说，在过去的年代里，连一些伟大的人物都“讲过一些违心的话”，这说明征税面非常的宽。因为有征话语捐的事，不管我们讲过什么，都可以不必自责：话是上面让说的嘛。但假如一切话语都是征来的捐税，事情就很不妙。那这些东西可以干什么？它是话，不是钱，既不能用来修水坝，也不能拿来修电站；只能搁在那里臭掉，供后人耻笑。当然，拿征募来的话语干什么，不是我该考虑的事，也许它还有别的用处我没有想到。我要说的是：征收话语捐的事古已有之。\n说话的人往往有种输捐纳税的意识\n，融化在血液里，落实在口头上。……', metadata={'author': '王小波', 'tags': '散文', 'name': '沉默的大多数 【中】王小波', 'id': '1ecbf48c-95ed-4571-bdc9-1f414b8a2afc', 'source': '读书笔记（文学）', 'date_start': 20130925}),
#  Document(page_content='不期而遇的唐总的QQ，竟开篇和我讨论出国交换的事。对于花钱买经历这种事，我们总是矛盾的。不想再花父母很多钱，但同时，又热切盼望live our lives to the fullest。但一切的剧本都是这样写的：父母大力支持说，这样好，要多出去走走，开开眼界。\n于是说，好吧，那就出去走走。\n写这段的时候已是十二月八日。唐总前不久告诉我说，面试过了，monsieur。——现在他确定大三上可以去多伦多大学了。\n我这里没有什么进展，host school list也没有更新，第一部preliminary的学校很少。虽然加拿大有滑铁卢和艾尔贝塔，但多伦多却是没有见着。\n我虽然未尝想过这个世界的恶意，但我目所能及的确发现许多比我过得轻松许多的人物。他们或许是因为家庭的富足使得未来并不成为某种驱策或者负担（这是主要的），或者因为对生活并非如我般挑剔和难以满足。\n我常常发现某些从小市镇来到大城市的孩子们，尽管无比优秀，却依然有某种我称之为“格调比较低”的性格特质——太计较，太精于细节，总给觉得不够宏大。但是转念一想，我在面对未来人生时所采取的自我主义态度，也许也正给人这样的感觉吧。', metadata={'name': '2013-OCT-23 多伦多', 'tags': '日常记趣', 'id': 'b79ddd99-6c12-45f0-ace0-4d87593351ec', 'source': '写作', 'date_start': 20131023, 'date_end': 20131023}),
#  Document(page_content='我们写书，是因为我们的孩子对我们不感兴趣。我们和不知名的世人交流，是因为我们在和自己的太太说话时，她堵上了自己的耳朵。\n就出租车司机这一状况，您会反驳我说，他是一个写作癖，而不是作家。那就应该先弄清概念了。一个每天给自己情人写四封信的女人不是个写作癖，而是个热恋中的女人。但是，我有一个朋友他把自己的情书都复印备份以便有朝一日发表出来，他就是一个写作癖。有写作癖不是有写信、写日记、写家族编年史的欲望（也就是说为自己或为自己的亲友而写），而是有写书的欲望（也就是说拥有不知名的读者大众）。在这意义上讲，出租车司机的激情和歌德的激情没什么两样。使歌德和那个出租车司机有区别的，不是激情不一样，而是激情的结果不一样。\n……（略）\n但是，通过反作用力的冲击，结果又对原因产生了影响。普遍疏离生成了写作癖，而普遍化的写作癖又反过来强化并加重了疏离。印刷机的发明从前曾使人们更好的互相理解，而在写作癖泛滥的时代，写书有了相反的意义：每个人都被自己的词语所包围，就像置身于重重的镜墙之中，任何外部声音都无法穿透进来。', metadata={'author': '【捷】米兰·昆德拉', 'tags': '小说', 'name': '笑忘录 【捷】米兰·昆德拉', 'id': '07e6c6bc-cb9e-48d5-a082-222d5c8806c2', 'source': '读书笔记（文学）', 'date_start': 20140114}),
#  Document(page_content='我曾经说过雅罗米尔是不太适合手淫的，他等待的是伟大的爱。但在这几个星期，他却绝望而疯狂地手淫，好像他是为了通过这个肮脏而富侮辱性的动作惩罚自己。因此他整天头疼，但是他对此感到幸福，因为头疼让他无暇注视街上穿着轻盈长裙的美丽女人，这头疼减轻了流行音乐里不知羞耻的赤裸裸的欲望；并且，在这可怕的头疼的折磨下，他可以比较容易地度过漫长的白天。\xa0\n\n他始终没有收到大学生的信。哪怕能收到一封别的什么信也好，不管是什么！哪怕有个人可以同意走进他的空虚！哪怕那个他寄去诗歌的著名诗人终于同意回复他片言只语！噢，他如果能写上几句热情洋溢的话该多好啊！\n（是的，我们说过他愿意用自己所有的诗歌来换取被当成男人来看待，但我们还得加上这样一句：既然已经无法被当成男人来看待，惟一能够安慰他的就是：至少可以被当成诗人来看待。）', metadata={'author': '【捷】米兰·昆德拉', 'tags': '小说', 'name': '生活在别处 【捷】米兰·昆德拉', 'id': '23bf00fd-e38c-48bd-b484-09403635e29a', 'source': '读书笔记（文学）', 'date_start': 20200126})]

# %%
question = "有一个诗人曾经写过类似“有人把国家带进沟里，但这些人说统治是一门艺术”的话。请找到出处。"
retriever_bm25.invoke(question)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =    8961.35 ms
# llama_print_timings:      sample time =       3.27 ms /    39 runs   (    0.08 ms per token, 11933.90 tokens per second)
# llama_print_timings: prompt eval time =     586.80 ms /    78 tokens (    7.52 ms per token,   132.92 tokens per second)
# llama_print_timings:        eval time =    1366.63 ms /    38 runs   (   35.96 ms per token,    27.81 tokens per second)
# llama_print_timings:       total time =    2014.10 ms /   116 tokens
# 2024-03-04 20:09:38.308 | INFO     | my_notion_companion.query_analyzer:parse_output:62 -
# Query Analyzer output
# keyword: ['有人把国家带进沟里，但这些人说统治是一门艺术']
# search domains:['诗人']
# 2024-03-04 20:09:38.308 | INFO     | my_notion_companion.retriever:_filter_documents:98 - filter found by query analyzer: ['诗人']
# 2024-03-04 20:09:38.327 | INFO     | my_notion_companion.retriever:_filter_documents:102 - No matched doc found based on query analyzer. Search all docs.
# [Document(page_content='马基雅维利还有这样一个观点：大多数的文明人是不择手段的利己主义者。他说，如果有人打算建立一个共和国，那么，他会发现，把共和国建立在农民中间，比建立在城市中间容易得多，因为城市可能已经变质了。即使是利己主义者，他的最明智的方针也要随他统治的民众来决定。因此，相比于依靠没有道德观念的民众，政治家在依靠有道德的民众时，行为要好得多。尽管伪善之心总能取得一定的成功，但适当的制度可以缩小这种成功的程度。', metadata={'author': '【英】罗素', 'tags': '人文', 'name': '西方哲学简史 【英】罗素', 'id': 'bad6847b-f1da-4ed2-9e7c-7defca4ad1a9', 'source': '读书笔记（文学）', 'date_start': 20161106}),
#  Document(page_content='这是我头一次在某个文学作品中感受到如此强烈的自恋情结而对此产生\n反感\n。在此之前，对于任何涉猎的文学作品，我至多也只是会觉得有些无聊。\n他那脱离现实的固执的原教旨主义（见“贝克农场”：我平素不喝茶，不喝咖啡，不吃黄油，不饮牛奶，也不吃鲜肉，因此，我就用不着为了得到这些去干活），接受资本主义优渥条件却又对文明生活的反叛（见“省俭有方”篇：一年里头只要工作六个星期，就足够支付我所有的生活开支），以及认为一切自然现象都是好的这种死板观念（见“种豆”篇：我又凭什么权利铲掉狗尾草，毁掉它们自古以来的百草园呢），无一不显出这是一个眼界狭窄，\n毫无社会经验\n的的傻瓜。\n有人把这本集子当做现代美国散文的范本，由以其中生动的自然景色，比如蚂蚁大战，潜水鸟等等，将梭罗描写的艺术性等同于其思想观念的价值。\n这使得《瓦尔登湖》获得了累世的名声——如果仅仅是傻瓜的呓语而被人遗忘，也轮不到我在这里大惊小怪。\n但正如毛泽东说过的，内容愈反动的作品而又愈带艺术性，就愈能毒害人民，就愈应该排斥。\n为什么这部作品有\n批判', metadata={'name': '2020-JUN-12 我们的文艺时代', 'tags': '日常记趣', 'id': '7408aa1b-ea03-4277-9d26-8f66d0d4816f', 'source': '写作', 'date_start': 20200612, 'date_end': 20200701}),
#  Document(page_content='1.\n我所认识的某些沾染过美国文化的同学，对香港的（在变成暴动之前的）游行带有一种同病相怜的共情。他们嘴上时常冒出什么“体制”，什么“民主”、“人权”；他们说出这些词的时候，大多还带着一种宛如思想脱离专治束缚后的领悟者的神态，真诚地觉得这些观念非常重要，俨然是生活中的基本构成。不但如此，他们也热衷于做个活动家，像个虔诚的传教士宣扬这种判别方法，而西方媒体报道中重复出现的素材就是他们的旧约。\n说起来，这个国家的人民确实有着擅长政治斗争的传统。毕竟在并不算长久的70年中，有相当部分的历史里，我们都过着一种“意识形态高于一切”的生活——尽管是持以这群游行同情者完全相反的立场。直到有人喊出“黑猫白猫，抓住耗子的就是好猫”，这个国家的GDP才嗖地一下，倏忽间跃迁到了世界第二。\n很多的政治问题，其实还是经济问题。\n换种说法，只有在经济出问题的情况下，政治才会变得重要起来；因为在经济不出问题的时候，不忙着赚钱的人就是真正的笨蛋。', metadata={'name': '嘘之默然♯♯Under Construction', 'tags': '嘘之默然', 'id': '0bb630f0-1908-494f-9531-f318696ad9e5', 'source': '写作', 'date_start': 20190802, 'date_end': 20191109}),
#  Document(page_content='使日本人变为好战民族的另一重要因素，是他们的一种错误信念，他们认为日本是个神圣的国家，系神所缔造，而且应该根据神的意志行事，并且征服世界。这种心理是由军阀御用的历史学家歪曲史实所造成的，为西洋人或中国人所不易了解，但是日本人却的确如此深信不疑。中国人也相信神佛，但是中国人把神佛当作道德的监护者，而不是战争的呵护者。日本人却认为日本称霸是神的旨意。\n从悠远的年代以来，日本的统治阶级一直相信神佛在战时总是站在大日本这一边的。当年元军没有征服日本，他们就认为那是神佛以无边的法力保护的结果，认为摧毁忽必烈庞大舰队的台风就是神佛的意旨。我修改本稿时，已在战后十多年了，还在日本箱根遇见一位老尼。她说人们应该信佛，日本打败元朝军队，就靠佛的法力的。日本人一直相信历代天皇都是神的嫡亲后裔。直至战后，日本历史学家得到言论自由，才用科学方法，把那些凝结在教科书里的神话，一口气吹散了。', metadata={'author': '蒋梦麟', 'tags': '散文', 'name': '西潮 【中】蒋梦麟', 'id': 'd3c5ae06-08fd-4217-ba8d-c180d8ead016', 'source': '读书笔记（文学）', 'date_start': 20140415}),
#  Document(page_content='除个别人，他们这样一些底层人家的青年聚在一起，基本上是不聊政治的，即便有人想将话题引往政治方面，通常也没人响应。“物以类聚，人以群分”，他们也是如此。哪一个同龄人如果太关心政治，朋友肯定是不多的。可能惹出不必要的麻烦倒是次要原因，主要原因是不感兴趣。“你们要关心国家大事，要把无产阶级文化大革命进行到底。”这一条语录，他们也能一张嘴就说出来，但那纯粹是一种条件反射，不过脑子的，好比一听到口号如雷就习惯于本能地举起手臂那样。', metadata={'author': '【中】梁晓声', 'tags': '小说', 'name': '在人间 【中】梁晓声', 'id': '33b15617-d84f-4d10-ae57-f206346e0690', 'source': '读书笔记（文学）', 'date_start': 20220925})]

# %%
scores_bm25
# Out:
# [True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  True,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]
